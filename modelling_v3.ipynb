# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', None)

df_sandal = pd.read_csv('C:\\Users\\Acer\\Downloads\\COMP4501-FYP\\eda_combined\\data\\sandal_final.csv')
df_sunscreen = pd.read_csv('C:\\Users\\Acer\\Downloads\\COMP4501-FYP\\eda_combined\\data\\sunscreen_final.csv')
df_wallet = pd.read_csv('C:\\Users\\Acer\\Downloads\\COMP4501-FYP\\eda_combined\\data\\wallet_final.csv')
df_pan = pd.read_csv('C:\\Users\\Acer\\Downloads\\COMP4501-FYP\\eda_combined\\data\\pan_final.csv')

# %%
df_sunscreen
# Out:
#                id  \
# 0        74170424
# 1     19980336891
# 2     18865050074
# 3      6862950349
# 4     22877274329
# ...           ...
# 3366  23876097498
# 3367   6041043049
# 3368  10137661400
# 3369  29135664098
# 3370  12750044648
#
#                                                                                                                                                                                                                                                             title  \
# 0                                                                                          skin aqua uv moisture milk spf 50 | moisture gel spf 30 | mild milk spf 25 | whitening milk spf 50 | tone up uv essence lavender | mint green spf 50+ | sunscreen mist
# 1                                                                                                                                                                                                             skin aqua uv whitening milk spf 50 pa++++ sunscreen
# 2                                                                                                               azarine bt21 bts body guard moisturizer sunscreen serum spf 50 pa++++ | magical luv sweet treats baby sunproof monster sun o clock young and free
# 3                                                                                                                                                                           kumara -  sunscreen wardah | madame gie madame protect me sunscreen spf 30 - skincare
# 4                                                                                                                                                                              madame gie madame protect me sunscreen spray mist spf 50 pa++++ | isi 50ml & 100ml
# ...                                                                                                                                                                                                                                                           ...
# 3366  [share in jar] skintific 10% niacinamide brightening 2% salicylic acid anti acne serum crystal eye cream barrier essence toner aha bha pha toner  5x ceramide moisturizer cleanser mugwort mask  acne spot hydrating serum soothing toner sunscreen barrier
# 3367                                                                                                                                                                                                         🩷hijrah store🩷 emina sun protection sunscreen series
# 3368                                                                                                                                                               ❤️ pamelo ❤️ azarine hydrasoothe sunscreen gel spf | sunscreen gel spf45 pa++++ | spf50 pa++++
# 3369                                                                                                                                                                  emina water gel moisturizer 30 g hydrating - paket 2in1 moisturizer, sunscreen, face wash |
# 3370                                                                                                                                                                                      whitelab uv shield tank sunscreen gel spf 50++ pa++++ whitelab surabaya
#
#       rating  reviews  initial_price  final_price  stock  favorite  \
# 0       4.92    16038        49900.0      41300.0   1580        10
# 1       4.78      112        61000.0      42500.0     50       128
# 2       5.00       18        65000.0      62200.0     16         5
# 3       4.79      567        31000.0      26500.0    402       229
# 4       4.86       35        34000.0      29000.0      9        50
# ...      ...      ...            ...          ...    ...       ...
# 3366    4.86        7         8800.0       6700.0   8976         5
# 3367    4.78      217        36500.0      31025.0     30        21
# 3368    4.86   155066        97500.0      65510.0    875     63305
# 3369    4.90        0        99675.0      58514.0      0         0
# 3370    4.90      679        84300.0      73341.0     39       131
#
#                 seller_name  seller_rating  seller_products  \
# 0        megabeautyfashindo           4.91              784
# 1            DesakiCosmetik           4.87               39
# 2           Made By Caramel           4.98              414
# 3     KUMARA STORE KOSMETIK           4.79              741
# 4              cherrishopie           4.82              460
# ...                     ...            ...              ...
# 3366                Geulyss           4.87              121
# 3367         HIJRAH_STORE33           4.78             1271
# 3368     Pamelo Beauty Shop           4.84              936
# 3369    Anaha Beauty Store            4.83              500
# 3370      Whitelab Surabaya           4.89               88
#
#       seller_chats_responded_percentage  seller_chat_time_reply  \
# 0                                    99                    1.00
# 1                                    92                    1.00
# 2                                   100                    1.00
# 3                                    92                    1.00
# 4                                    81                    1.00
# ...                                 ...                     ...
# 3366                                 84                    1.00
# 3367                                 65                    2.66
# 3368                                100                    1.65
# 3369                                 80                    0.72
# 3370                                 83                    1.27
#
#       seller_joined_date  seller_followers    sold       brand  flash_sale  \
# 0               7.000000            114400   18710   skin aqua           0
# 1               0.333333              4200     468   skin aqua           0
# 2               5.000000              4400      40     azarine           0
# 3               4.000000             61100    2700      wardah           0
# 4               8.000000              9600     138  madame gie           0
# ...                  ...               ...     ...         ...         ...
# 3366            7.000000            104700      24   skintific           0
# 3367            6.258727             22959     254       emina           0
# 3368            5.021218           1047971  188780     azarine           0
# 3369            9.081451             22388       0       emina           0
# 3370           10.119097             17552     868      others           0
#
#          gmv_cal shipped_from formulation      spf country_of_origin  \
# 0       413000.0  Jabodetabek         gel     high            others
# 1     19890000.0  Jabodetabek      liquid     high            others
# 2      2488000.0      Sumatra      liquid     high            others
# 3     71550000.0         Java      others   medium            others
# 4      4002000.0      Unknown       spray     high            others
# ...          ...          ...         ...      ...               ...
# 3366    160800.0  Jabodetabek       cream  unknown            others
# 3367         0.0      Unknown      liquid   medium         indonesia
# 3368         0.0  Jabodetabek         gel   medium            others
# 3369         0.0         Java         gel  unknown            others
# 3370         0.0         Java         gel     high            others
#
#       variations_count  voucher_status  image_count  video_count  discount  \
# 0                    7               0            8            0    8600.0
# 1                    0               0            6            0   18500.0
# 2                    5               0            8            0    2800.0
# 3                    4               0            6            0    4500.0
# 4                    2               0            7            0    5000.0
# ...                ...             ...          ...          ...       ...
# 3366                45               0            5            0    2100.0
# 3367                 6               0            5            0    5475.0
# 3368                15               1            7            1   31990.0
# 3369                 8               0            8            0   41161.0
# 3370                 1               0            9            0   10959.0
#
#       storage_duration_months  volume_ml volume_group  spf_num  \
# 0                        24.0        NaN      unknown        3
# 1                        12.0        NaN      unknown        3
# 2                         NaN        NaN      unknown        3
# 3                        24.0        NaN      unknown        2
# 4                        24.0       50.0        small        3
# ...                       ...        ...          ...      ...
# 3366                     12.0        NaN      unknown        0
# 3367                     24.0       50.0        small        2
# 3368                     24.0        NaN      unknown        2
# 3369                     24.0        NaN      unknown        0
# 3370                     12.0        NaN      unknown        3
#
#       discount_percentage  rating_credibility  log_reviews  log_final_price  \
# 0               17.234469            4.920000     9.682779        10.628642
# 1               30.327869            3.860179     4.727388        10.657283
# 2                4.307692            0.890404     2.944439        11.038126
# 3               14.516129            4.789886     6.342121        10.184938
# 4               14.705882            1.634785     3.583519        10.275086
# ...                   ...                 ...          ...              ...
# 3366            23.863636            0.339645     2.079442         8.810012
# 3367            15.000000            4.656975     5.384495        10.342581
# 3368            32.810256            4.860000    11.951613        11.089973
# 3369            41.295209            0.000000     0.000000        10.977038
# 3370            13.000000            4.899988     6.522093        11.202889
#
#       log_initial_price  log_stock  log_favorite   log_sold  log_gmv_cal  \
# 0             10.817796   7.365813      2.397895   9.836867    12.931205
# 1             11.018646   3.931826      4.859812   6.150603    16.805728
# 2             11.082158   2.833213      1.791759   3.713572    14.726990
# 3             10.341775   5.998937      5.438079   7.901377    18.085907
# 4             10.434145   2.302585      3.931826   4.934474    15.202305
# ...                 ...        ...           ...        ...          ...
# 3366           9.082621   9.102421      1.791759   3.218876    11.987923
# 3367          10.505095   3.433987      3.091042   5.541264     0.000000
# 3368          11.487618   6.775366     11.055735  12.148343     0.000000
# 3369          11.509680   0.000000      0.000000   0.000000     0.000000
# 3370          11.342149   3.688879      4.882802   6.767343     0.000000
#
#       log_seller_followers  log_seller_products  log_discount     z_sold  \
# 0                11.647465             6.665684      9.059634   1.289440
# 1                 8.343078             3.688879      9.825580  -0.111587
# 2                 8.389587             6.028279      7.937732  -0.144458
# 3                11.020284             6.609349      8.412055   0.059836
# 4                 9.169623             6.133398      8.517393  -0.136932
# ...                    ...                  ...           ...        ...
# 3366             11.558864             4.804021      7.650169  -0.145687
# 3367             10.041509             7.148346      8.608130  -0.128023
# 3368             13.862367             6.842683     10.373210  14.351203
# 3369             10.016325             6.216606     10.625271  -0.147531
# 3370              9.772980             4.488636      9.302008  -0.080866
#
#       z_rating_credibility
# 0                 1.552195
# 1                 1.010777
# 2                -0.506357
# 3                 1.485725
# 4                -0.126084
# ...                    ...
# 3366             -0.787717
# 3367              1.417826
# 3368              1.521543
# 3369             -0.961228
# 3370              1.541971
#
# [3371 rows x 46 columns]

# %% [markdown]
# ## Config

# %%
import numpy as np

CONFIG = {
    "random_seed": 42,
    "test_size": 0.2,
    "val_size": 0.2,
    "cv_folds": 5,

    # "stage1_trials": 20,
    "stage2_trials": 100,

    "early_stopping_rounds": 50,

    "low_card_threshold": 10,

    "target_cols": ["z_sold", "z_rating_credibility"],

    "metrics": ["rmse", "mae", "r2"]
}

# %% [markdown]
# ## Data Split

# %%
from sklearn.model_selection import train_test_split

def split_data(df, config):
    train_val, test = train_test_split(
        df,
        test_size=config["test_size"],
        random_state=config["random_seed"]
    )

    train, val = train_test_split(
        train_val,
        test_size=config["val_size"],
        random_state=config["random_seed"]
    )

    return train, val, test

# %% [markdown]
# ## Feature Type Detection

# %%
def detect_feature_types(df):
    numeric = []
    categorical = []
    binary = []

    for col in df.columns:

        # skip ID-like columns (high cardinality string)
        if df[col].dtype == "object" and df[col].nunique() > 0.9 * len(df):
            continue

        if df[col].nunique() == 2:
            binary.append(col)

        elif pd.api.types.is_numeric_dtype(df[col]):
            numeric.append(col)

        else:
            categorical.append(col)

    return numeric, categorical, binary

def select_features(df):
    cols = df.columns.tolist()

    drop_cols = {
        "target",
        "title",
        "sold",
        "reviews",
        "gmv_cal",
        "rating",
        "rating_credibility",
        "z_sold",
        "z_rating_credibility",
        "id",
        "seller_name",
        #"favorite"
    }

    drop_log_related = {
        "log_sold",
        "log_reviews",
        "log_gmv_cal",
        #"log_favorite"
    }

    selected = []

    for c in cols:
        if c in drop_cols or c in drop_log_related:
            continue

        selected.append(c)

    return selected

# %% [markdown]
# ## Feature Split

# %%
def split_features_by_model(df, num_cols):

    log_cols = [c for c in num_cols if c.startswith("log_")]

    raw_cols = []
    for c in log_cols:
        raw = c.replace("log_", "")
        if raw in df.columns:
            raw_cols.append(raw)

    # numeric that are not log or raw pairs
    other_numeric = [
        c for c in num_cols
        if not c.startswith("log_") and c not in raw_cols
    ]

    return log_cols, raw_cols, other_numeric

# %% [markdown]
# ## Target Engine (PCA + Bootstrap)

# %%
from sklearn.decomposition import PCA

def bootstrap_pca_weights(train, cols, n_boot=200):
    weights = []

    X = train[cols].values

    for _ in range(n_boot):
        idx = np.random.choice(len(X), len(X), replace=True)
        sample = X[idx]

        pca = PCA(n_components=1)
        pca.fit(sample)

        w = pca.components_[0]

        # Align sign
        if w[0] < 0:
            w = -w

        weights.append(w)

    weights = np.array(weights)

    mean_w = weights.mean(axis=0)
    std_w = weights.std(axis=0)

    return mean_w, std_w


def create_target(df, weights, cols):
    return df[cols].values @ weights

# %% [markdown]
# ## Preprocessing Pipelines

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer

def build_linear_pipeline(df, num_cols, cat_cols):

    log_cols, _, other_numeric = split_features_by_model(df, num_cols)

    linear_num_cols = log_cols + other_numeric

    print("\n[DEBUG] Linear features:")
    print(linear_num_cols[:10])

    num_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler())
    ])

    cat_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
        ("onehot", OneHotEncoder(handle_unknown="ignore"))
    ])

    return ColumnTransformer([
        ("num", num_pipe, linear_num_cols),
        ("cat", cat_pipe, cat_cols)
    ])


def build_tree_pipeline(df, num_cols, cat_cols):

    log_cols, raw_cols, other_numeric = split_features_by_model(df, num_cols)

    tree_num_cols = raw_cols + other_numeric

    print("\n[DEBUG] Tree features:")
    print(tree_num_cols[:10])

    num_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median"))
    ])

    cat_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
        ("onehot", OneHotEncoder(handle_unknown="ignore"))
    ])

    return ColumnTransformer([
        ("num", num_pipe, tree_num_cols),
        ("cat", cat_pipe, cat_cols)
    ])

# %% [markdown]
# ## List of Models

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

import xgboost as xgb
import lightgbm as lgb
from catboost import CatBoostRegressor


def get_models():
    return {
        # -------------------------
        # Baselines (VERY IMPORTANT)
        # -------------------------
        "linear_regression": LinearRegression(),
        "ridge": Ridge(),
        "lasso": Lasso(),
        "elastic_net": ElasticNet(),

        # -------------------------
        # Tree Models
        # -------------------------
        "random_forest": RandomForestRegressor(),
        "extra_trees": ExtraTreesRegressor(),

        # -------------------------
        # Boosting (Strongest)
        # -------------------------
        "xgboost": xgb.XGBRegressor(tree_method="hist"),
        "lightgbm": lgb.LGBMRegressor(),
        "catboost": CatBoostRegressor(verbose=0),

        # -------------------------
        # Others
        # -------------------------
        "svr": SVR(),
        "knn": KNeighborsRegressor()
    }

# %% [markdown]
# ## Metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def evaluate(y_true, y_pred):
    return {
        "rmse": np.sqrt(mean_squared_error(y_true, y_pred)),
        "mae": mean_absolute_error(y_true, y_pred),
        "r2": r2_score(y_true, y_pred)
    }

# %% [markdown]
# ### Stage 1 - Fast Screening

# %%
from sklearn.model_selection import cross_validate

def stage1_search(models, X, y, preprocessors, config):

    results = []

    scoring = {
        "rmse": "neg_root_mean_squared_error",
        "mae": "neg_mean_absolute_error",
        "r2": "r2"
    }

    for name, model in models.items():

        pipe = Pipeline([
            ("prep", preprocessors[name]),
            ("model", model)
        ])

        scores = cross_validate(
            pipe,
            X,
            y,
            cv=config["cv_folds"],
            scoring=scoring,
            return_train_score=False
        )

        results.append({
            "model": name,
            "cv_rmse_mean": -scores["test_rmse"].mean(),
            "cv_rmse_sd": scores["test_rmse"].std(),
            "cv_mae_mean": -scores["test_mae"].mean(),
            "cv_r2_mean": scores["test_r2"].mean()
        })

    # sort
    results_df = pd.DataFrame(results).sort_values("cv_rmse_mean")

    # select top models
    top_models = results_df.head(3).to_dict("records")

    return top_models, results_df

# %% [markdown]
# ### Stage 2 - Optuna Tuning

# %%
import optuna
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

def tune_model(model_name, X, y, preprocessor, config):

    def objective(trial):

        # -------------------------
        # LINEAR MODELS
        # -------------------------
        if model_name == "linear_regression":
            model = LinearRegression()

        elif model_name == "ridge":
            params = {
                "alpha": trial.suggest_float("alpha", 1e-3, 10.0, log=True)
            }
            model = Ridge(**params)

        elif model_name == "lasso":
            params = {
                "alpha": trial.suggest_float("alpha", 1e-4, 1.0, log=True)
            }
            model = Lasso(**params)

        elif model_name == "elastic_net":
            params = {
                "alpha": trial.suggest_float("alpha", 1e-4, 1.0, log=True),
                "l1_ratio": trial.suggest_float("l1_ratio", 0.0, 1.0)
            }
            model = ElasticNet(**params)

        # -------------------------
        # TREE MODELS
        # -------------------------
        elif model_name == "random_forest":
            params = {
                "n_estimators": trial.suggest_int("n_estimators", 100, 400),
                "max_depth": trial.suggest_int("max_depth", 5, 30),
                "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
                "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 5),
                "max_features": trial.suggest_categorical("max_features", ["sqrt", "log2"])
            }
            model = RandomForestRegressor(**params)

        elif model_name == "extra_trees":
            params = {
                "n_estimators": trial.suggest_int("n_estimators", 100, 400),
                "max_depth": trial.suggest_int("max_depth", 5, 30),
                "min_samples_split": trial.suggest_int("min_samples_split", 2, 10),
                "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 5)
            }
            model = ExtraTreesRegressor(**params)

        # -------------------------
        # BOOSTING MODELS
        # -------------------------
        elif model_name == "xgboost":
            params = {
                "n_estimators": trial.suggest_int("n_estimators", 200, 800),
                "max_depth": trial.suggest_int("max_depth", 3, 10),
                "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
                "subsample": trial.suggest_float("subsample", 0.6, 1.0),
                "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),
                "gamma": trial.suggest_float("gamma", 0, 5),
                "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 10, log=True)
            }
            model = xgb.XGBRegressor(tree_method="hist", **params)

        elif model_name == "lightgbm":
            params = {
                "n_estimators": trial.suggest_int("n_estimators", 200, 800),
                "num_leaves": trial.suggest_int("num_leaves", 20, 150),
                "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
                "feature_fraction": trial.suggest_float("feature_fraction", 0.6, 1.0),
                "bagging_fraction": trial.suggest_float("bagging_fraction", 0.6, 1.0),
                "min_child_samples": trial.suggest_int("min_child_samples", 5, 50)
            }
            model = lgb.LGBMRegressor(**params)

        elif model_name == "catboost":
            params = {
                "iterations": trial.suggest_int("iterations", 200, 800),
                "depth": trial.suggest_int("depth", 4, 10),
                "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.2, log=True),
                "l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 10),
                "border_count": trial.suggest_int("border_count", 32, 255),
                "verbose": 0
            }
            model = CatBoostRegressor(**params)

        # -------------------------
        # SVR
        # -------------------------
        elif model_name == "svr":
            params = {
                "C": trial.suggest_float("C", 0.1, 100, log=True),
                "epsilon": trial.suggest_float("epsilon", 0.01, 1.0),
                "kernel": trial.suggest_categorical("kernel", ["rbf", "linear"]),
                "gamma": trial.suggest_categorical("gamma", ["scale", "auto"])
            }
            model = SVR(**params)

        # -------------------------
        # KNN
        # -------------------------
        elif model_name == "knn":
            params = {
                "n_neighbors": trial.suggest_int("n_neighbors", 3, 20),
                "weights": trial.suggest_categorical("weights", ["uniform", "distance"]),
                "p": trial.suggest_int("p", 1, 2)
            }
            model = KNeighborsRegressor(**params)

        else:
            raise ValueError(f"No tuning defined for {model_name}")

        # -------------------------
        # PIPELINE
        # -------------------------
        pipe = Pipeline([
            ("prep", preprocessor),
            ("model", model)
        ])

        score = cross_val_score(
            pipe,
            X,
            y,
            cv=config["cv_folds"],
            scoring="neg_root_mean_squared_error"
        ).mean()

        return -score

    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=config["stage2_trials"])

    return study.best_params

# %% [markdown]
# ### Final Training

# %%
def train_final(model, preprocessor, X_train, y_train):
    pipe = Pipeline([
        ("prep", preprocessor),
        ("model", model)
    ])
    pipe.fit(X_train, y_train)
    return pipe

# %% [markdown]
# ## Weighted Ensemble Model

# %%
def weighted_ensemble(preds, rmses):
    weights = 1 / np.array(rmses)
    weights /= weights.sum()

    final_pred = sum(w * p for w, p in zip(weights, preds))

    return final_pred, weights

def get_weighted_ensemble_importance(
    trained_models,
    weights,
    X_train,
    top_n=10
):
    import pandas as pd
    import numpy as np

    all_importances = []

    for model, w in zip(trained_models, weights):

        m = model.named_steps["model"]
        prep = model.named_steps["prep"]

        # Get feature names
        try:
            feature_names = prep.get_feature_names_out()
        except:
            feature_names = [f"f_{i}" for i in range(prep.transform(X_train).shape[1])]

        # Get importance
        if hasattr(m, "feature_importances_"):
            imp = m.feature_importances_

        elif hasattr(m, "coef_"):
            imp = np.abs(m.coef_)

        else:
            continue

        df = pd.DataFrame({
            "feature": feature_names,
            "importance": imp * w   # 🔥 weighted
        })

        all_importances.append(df)

    # Combine all
    final_df = pd.concat(all_importances)

    # Aggregate
    final_df = final_df.groupby("feature")["importance"].sum().reset_index()

    final_df = final_df.sort_values("importance", ascending=False).head(top_n)

    return final_df

def plot_ensemble_importance(importance_df):

    import matplotlib.pyplot as plt
    
    plt.barh(importance_df["feature"], importance_df["importance"])
    plt.gca().invert_yaxis()

    plt.title("Weighted Ensemble Feature Importance")
    plt.xlabel("Weighted Importance")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Plot Feature Importance

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

def plot_feature_importance(model, prep, X_train, top_n=10, title="Feature Importance"):

    # Get transformed feature names
    try:
        feature_names = prep.get_feature_names_out()
    except:
        feature_names = [f"f_{i}" for i in range(prep.transform(X_train).shape[1])]

    # Get importance
    if hasattr(model, "feature_importances_"):
        importance = model.feature_importances_

    elif hasattr(model, "coef_"):
        importance = np.abs(model.coef_)

    else:
        print("[WARN] Model does not support feature importance")
        return

    # Create DataFrame
    feat_imp = pd.DataFrame({
        "feature": feature_names,
        "importance": importance
    })

    feat_imp = feat_imp.sort_values("importance", ascending=False).head(top_n)

    # Plot
    plt.barh(feat_imp["feature"], feat_imp["importance"])
    plt.gca().invert_yaxis()

    plt.title(title)
    plt.xlabel("Importance")
    plt.ylabel("Feature")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## SHAP Analysis

# %%
import numpy as np
import pandas as pd
import shap

def shap_thresholds_with_interpretation(
    X,
    shap_values,
    feature_names,
    top_n=10
):

    shap_abs = np.abs(shap_values).mean(axis=0)

    importance = pd.DataFrame({
        "feature": feature_names,
        "importance": shap_abs
    }).sort_values("importance", ascending=False)

    top_features = importance.head(top_n)["feature"].values

    results = []

    for f in top_features:

        # -------------------------
        # Handle categorical
        # -------------------------
        if "cat__" in f:
            results.append({
                "feature": f,
                "threshold_log": None,
                "threshold_real": None,
                "interpretation": "Categorical feature — interpret via presence/absence",
                "insight": "This category impacts prediction when present"
            })
            continue

        try:
            idx = feature_names.tolist().index(f)

            x = X[:, idx]
            y = shap_values[:, idx]

            # sort
            order = np.argsort(x)
            x_sorted = x[order]
            y_sorted = y[order]

            # slope
            slope = np.gradient(y_sorted, x_sorted)
            threshold = x_sorted[np.argmin(slope)]

            # -------------------------
            # Convert log back to real numbers
            # -------------------------
            if "log_" in f:
                real_value = np.exp(threshold) - 1
                scale_type = "log"
            else:
                real_value = threshold
                scale_type = "raw"

            # -------------------------
            # Interpretation
            # -------------------------
            if scale_type == "log":
                interpretation = f"{f.replace('num__log_', '')} > {real_value:.2f}"
            else:
                interpretation = f"{f.replace('num__', '')} > {real_value:.2f}"

            insight = "Above this threshold → strong positive impact on success score"

            results.append({
                "feature": f,
                "threshold_log": float(threshold),
                "threshold_real": float(real_value),
                "interpretation": interpretation,
                "insight": insight
            })

        except Exception as e:
            results.append({
                "feature": f,
                "threshold_log": None,
                "threshold_real": None,
                "interpretation": "Failed",
                "insight": str(e)
            })

    return pd.DataFrame(results)

# %%
def validate_shap_input(X, feature_names):
    import pandas as pd
    import numpy as np

    df = pd.DataFrame(X, columns=feature_names)

    bad_cols = []
    for col in df.columns:
        if df[col].dtype == "object":
            bad_cols.append(col)

    if bad_cols:
        print("\n[WARNING] Non-numeric columns detected for SHAP:")
        print(bad_cols)

    # keep only numeric
    numeric_df = df.select_dtypes(include=[np.number])

    dropped = set(df.columns) - set(numeric_df.columns)
    if dropped:
        print("\n[INFO] Dropping incompatible columns:")
        print(list(dropped))

    return numeric_df.values, numeric_df.columns

# %% [markdown]
# ### Binning and PDP

# %%
def binning_threshold(x, y, bins=10):
    df = pd.DataFrame({"x": x, "y": y})
    df["bin"] = pd.qcut(df["x"], bins, duplicates="drop")

    grouped = df.groupby("bin")["y"].mean()

    best_bin = grouped.idxmax()

    return best_bin

from sklearn.inspection import PartialDependenceDisplay

def plot_pdp(model, X, features):
    PartialDependenceDisplay.from_estimator(model, X, features)
    plt.show()

# %%
import time
import numpy as np

def log(msg):
    print(f"[INFO] {msg}")

def log_section(title):
    print("\n" + "="*50)
    print(f"[STAGE] {title}")
    print("="*50)

# %% [markdown]
# ## Feature Recommendations

# %%
def generate_feature_recommendations(
    model,
    X,
    top_features,
    n_bins=10
):
    import pandas as pd
    import numpy as np

    def create_bins(series, n_bins=10):
        try:
            return pd.qcut(series, n_bins, duplicates="drop")
        except:
            return pd.cut(series, n_bins)

    def summarize_bins(feature, X, preds):
        df = pd.DataFrame({
            "feature": X[feature],
            "pred": preds
        })

        if pd.api.types.is_numeric_dtype(df["feature"]):
            df["bin"] = create_bins(df["feature"])
            summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
            summary.columns = ["feature_bin", "predicted_mean"]

            # extract min/max
            summary["feature_min"] = summary["feature_bin"].apply(lambda x: x.left if hasattr(x, "left") else None)
            summary["feature_max"] = summary["feature_bin"].apply(lambda x: x.right if hasattr(x, "right") else None)

        else:
            summary = df.groupby("feature")["pred"].mean().reset_index()
            summary.columns = ["feature_bin", "predicted_mean"]

        return summary.sort_values("predicted_mean", ascending=False)

    def derive_recommendation(feature, X, bin_summary):
        series = X[feature]
        is_numeric = pd.api.types.is_numeric_dtype(series)

        if bin_summary.empty:
            return None

        best_row = bin_summary.iloc[0]

        if is_numeric:
            current_typical = series.median()

            if "feature_min" in bin_summary.columns:
                recommended_range = f"{best_row['feature_min']:.4g} to {best_row['feature_max']:.4g}"
            else:
                recommended_range = None

            return {
                "feature": feature,
                "current_typical_value": round(float(current_typical), 4),
                "recommended_target_or_range": recommended_range,
                "best_predicted_bin_mean": round(float(best_row["predicted_mean"]), 6),
                "note": "Optimal range based on model prediction"
            }

        else:
            current_mode = series.mode(dropna=True)
            current_mode = current_mode.iloc[0] if len(current_mode) > 0 else None

            return {
                "feature": feature,
                "current_typical_value": current_mode,
                "recommended_target_or_range": str(best_row["feature_bin"]),
                "best_predicted_bin_mean": round(float(best_row["predicted_mean"]), 6),
                "note": "Best performing category"
            }

    # -------------------------
    # Run pipeline
    # -------------------------
    preds = model.predict(X)

    rows = []

    for f in top_features:
        if f not in X.columns:
            continue

        summary = summarize_bins(f, X, preds)
        row = derive_recommendation(f, X, summary)

        if row:
            rows.append(row)

    return pd.DataFrame(rows)

# %% [markdown]
# # Main Pipeline

# %%
def run_pipeline(df):

    start_time = time.time()

    # -------------------------
    # 1. Split
    # -------------------------
    log_section("1. DATA SPLIT")

    train, val, test = split_data(df, CONFIG)

    log(f"Train shape: {train.shape}")
    log(f"Validation shape: {val.shape}")
    log(f"Test shape: {test.shape}")

    # -------------------------
    # 2. Target (PCA + Bootstrap)
    # -------------------------
    log_section("2. TARGET ENGINE (PCA + BOOTSTRAP)")

    weights, std = bootstrap_pca_weights(train, CONFIG["target_cols"])

    log(f"PCA Weights: {weights}")
    log(f"Weight STD: {std}")

    train["target"] = create_target(train, weights, CONFIG["target_cols"])
    val["target"] = create_target(val, weights, CONFIG["target_cols"])
    test["target"] = create_target(test, weights, CONFIG["target_cols"])

    # -------------------------
    # Normalize PCA weights (sum to 100%)
    # -------------------------
    log_section("PCA NORMALIZED WEIGHTS (%)")

    # absolute weights to avoid sign issue
    w_abs = np.abs(weights)

    # normalize to sum = 1
    w_pct = w_abs / np.sum(w_abs)

    # convert std to percentage space
    std_pct = std / np.sum(w_abs)

    # print nicely
    for col, w, s in zip(CONFIG["target_cols"], w_pct, std_pct):
        log(f"{col}: {w*100:.2f}% ± {s*100:.2f}%")

    # optional: store for later use
    pca_weight_summary = pd.DataFrame({
        "component": CONFIG["target_cols"],
        "weight_raw": weights,
        "weight_std": std,
        "weight_pct": w_pct * 100,
        "std_pct": std_pct * 100
    })

    print("\nPCA Weight Summary Table:")
    print(pca_weight_summary.to_string(index=False))

    # -------------------------
    # 3. Feature Selection
    # -------------------------
    log_section("3. FEATURE SELECTION")

    feature_cols = select_features(train)
    log(f"Selected features: {len(feature_cols)}")

    X_train = train[feature_cols]
    y_train = train["target"]

    X_val = val[feature_cols]
    y_val = val["target"]

    X_test = test[feature_cols]
    y_test = test["target"]

    # -------------------------
    # 4. Feature types
    # -------------------------
    log_section("4. FEATURE TYPE DETECTION")

    num_cols, cat_cols, bin_cols = detect_feature_types(X_train)

    log(f"# Numeric: {len(num_cols)}")
    log(f"# Categorical: {len(cat_cols)}")
    log(f"# Binary: {len(bin_cols)}")

    # -------------------------
    # 5. Pipelines
    # -------------------------
    log_section("5. BUILD PIPELINES")

    linear_prep = build_linear_pipeline(X_train, num_cols, cat_cols)
    tree_prep = build_tree_pipeline(X_train, num_cols, cat_cols)

    # -------------------------
    # 6. Models
    # -------------------------
    log_section("6. MODEL REGISTRY")

    models = get_models()

    # -------------------------
    # Model family mapping
    # -------------------------
    linear_models = {
        "linear_regression",
        "ridge",
        "lasso",
        "elastic_net"
    }

    tree_models = {
        "random_forest",
        "extra_trees",
        "xgboost",
        "lightgbm",
        "catboost"
    }

    other_models = {
        "svr",
        "knn"
    }

    # -------------------------
    # Build preprocessors dynamically
    # -------------------------
    preprocessors = {}

    for name in models.keys():
        if name in linear_models:
            preprocessors[name] = linear_prep

        elif name in tree_models:
            preprocessors[name] = tree_prep
        
        elif name in other_models:
            preprocessors[name] = linear_prep

        else:
            raise ValueError(f"Unknown model type: {name}")

    log(f"Preprocessors assigned for {len(preprocessors)} models")

    # -------------------------
    # 7. Stage 1 Search + Stage 2 Tuning
    # -------------------------
    log_section("7. STAGE 1 SEARCH")

    top_models, all_results = stage1_search(
        models, X_train, y_train, preprocessors, CONFIG
    )

    log_section("STAGE 1 MODEL PERFORMANCE TABLE")

    stage1_df = all_results.copy()

    print(stage1_df.to_string(index=False))

    # plot
    plt.figure()
    plt.barh(stage1_df["model"], stage1_df["cv_rmse_mean"])
    plt.xlabel("RMSE")
    plt.title("Stage 1 Model Performance (Lower is Better)")
    plt.gca().invert_yaxis()
    plt.show()

    log(f"Top models: {[m['model'] for m in top_models]}")
    
    
    log_section("STAGE 2: HYPERPARAMETER TUNING")

    tuned_models = {}

    for m in top_models:
        name = m["model"]

        log(f"Tuning model: {name}")

        best_params = tune_model(
            name,
            X_train,
            y_train,
            preprocessors[name],
            CONFIG
        )

        log(f"Best params for {name}: {best_params}")

        # rebuild model with best params
        if name == "xgboost":
            model = xgb.XGBRegressor(**best_params)

        elif name == "lightgbm":
            model = lgb.LGBMRegressor(**best_params)

        elif name == "catboost":
            model = CatBoostRegressor(**best_params)

        elif name == "random_forest":
            model = RandomForestRegressor(**best_params)

        elif name == "ridge":
            model = Ridge(**best_params)

        elif name == "elastic_net":
            model = ElasticNet(**best_params)

        else:
            continue

        pipe = Pipeline([
            ("prep", preprocessors[name]),
            ("model", model)
        ])

        pipe.fit(X_train, y_train)

        tuned_models[name] = pipe
    

    tuning_summary = []
    
    tuning_summary.append({
        "model": name,
        "n_trials": CONFIG["stage2_trials"],
        "best_params": best_params
    })

    tuning_summary_df = pd.DataFrame(tuning_summary)
    print("\nTuning Summary:")
    print(tuning_summary_df.to_string(index=False))

    # -------------------------
    # 8. Train finalists + table
    # -------------------------
    log_section("8. TRAIN FINAL MODELS")

    trained_models = []
    val_preds = []
    rmses = []
    results_table = []

    for m in top_models:
        name = m["model"]

        log(f"Training: {name}")

        pipe = train_final(
            models[name],
            preprocessors[name],
            X_train, y_train
        )

        pred = pipe.predict(X_val)
        metrics = evaluate(y_val, pred)

        trained_models.append(pipe)
        val_preds.append(pred)
        rmses.append(metrics["rmse"])

        results_table.append({
            "model": name,
            "rmse": metrics["rmse"],
            "mae": metrics["mae"],
            "r2": metrics["r2"]
        })

    # -------------------------
    # STAGE 1 vs STAGE 2 COMPARISON (FIXED)
    # -------------------------
    log_section("MODEL IMPROVEMENT (STAGE 1 vs STAGE 2)")

    # Convert results_table to DataFrame for easy lookup
    results_df_stage2 = pd.DataFrame(results_table)

    comparison_rows = []

    for m in top_models:

        name = m["model"]

        # Stage 1 (CV)
        stage1_rmse = m["cv_rmse_mean"]
        stage1_mae = m["cv_mae_mean"]
        stage1_r2 = m["cv_r2_mean"]

        # Stage 2 (Validation) — match by model name
        row_stage2 = results_df_stage2[results_df_stage2["model"] == name]

        if row_stage2.empty:
            continue  # skip if not found (safety)

        row_stage2 = row_stage2.iloc[0]

        stage2_rmse = row_stage2["rmse"]
        stage2_mae = row_stage2["mae"]
        stage2_r2 = row_stage2["r2"]

        comparison_rows.append({
            "model": name,

            # Stage 1
            "stage1_rmse": stage1_rmse,
            "stage1_mae": stage1_mae,
            "stage1_r2": stage1_r2,

            # Stage 2
            "stage2_rmse": stage2_rmse,
            "stage2_mae": stage2_mae,
            "stage2_r2": stage2_r2,

            # Improvement
            "rmse_improvement": stage1_rmse - stage2_rmse,
            "mae_improvement": stage1_mae - stage2_mae,
            "r2_improvement": stage2_r2 - stage1_r2
        })

    comparison_df = pd.DataFrame(comparison_rows)

    print(comparison_df.to_string(index=False))

    # -------------------------
    # TOP MODELS FEATURE IMPORTANCE (NEW)
    # -------------------------
    log_section("TOP MODELS FEATURE IMPORTANCE")

    top3_idx = np.argsort(rmses)[:3]

    plt.figure(figsize=(12, 6))

    for i, idx in enumerate(top3_idx):
        model = trained_models[idx]
        name = top_models[idx]["model"]

        plt.figure(figsize=(12,5))

        plot_feature_importance(
            model.named_steps["model"],
            model.named_steps["prep"],
            X_train,
            top_n=10,
            title=f"{name} (R2={results_table[idx]['r2']:.3f})"
        )

    plt.tight_layout()
    plt.show()

    # -------------------------
    # 9. Ensemble
    # -------------------------
    log_section("9. ENSEMBLE")

    ensemble_pred, weights = weighted_ensemble(val_preds, rmses)
    ensemble_metrics = evaluate(y_val, ensemble_pred)

    results_table.append({
        "model": "ensemble",
        "rmse": ensemble_metrics["rmse"],
        "mae": ensemble_metrics["mae"],
        "r2": ensemble_metrics["r2"]
    })

    # -------------------------
    # ENSEMBLE FEATURE IMPORTANCE
    # -------------------------
    log_section("ENSEMBLE FEATURE IMPORTANCE")

    ensemble_importance_df = get_weighted_ensemble_importance(
        trained_models=trained_models,
        weights=weights,
        X_train=X_train,
        top_n=10
    )

    print(ensemble_importance_df.to_string(index=False))

    plot_ensemble_importance(ensemble_importance_df)

    # -------------------------
    # 10. PRINT TABLE
    # -------------------------
    log_section("10. MODEL PERFORMANCE TABLE")

    results_df = pd.DataFrame(results_table).sort_values("rmse")

    print(results_df.to_string(index=False))

    best_model_idx = np.argmin(rmses)
    best_model = trained_models[best_model_idx]

    log(f"Best model: {top_models[best_model_idx]['model']}")

    # -------------------------
    # 11. SHAP ANALYSIS (FIXED)
    # -------------------------
    log_section("11. SHAP ANALYSIS")

    try:
        X_sample = X_val.sample(min(1000, len(X_val)), random_state=42)

        # Extract pipeline parts
        prep = best_model.named_steps["prep"]
        model = best_model.named_steps["model"]

        X_transformed = prep.transform(X_sample)

        # convert to dense if sparse
        if hasattr(X_transformed, "toarray"):
            X_transformed = X_transformed.toarray()

        # get feature names
        try:
            feature_names = prep.get_feature_names_out()
        except:
            feature_names = [f"f_{i}" for i in range(X_transformed.shape[1])]

        # VALIDATE + CLEAN
        X_transformed, feature_names = validate_shap_input(
            X_transformed,
            feature_names
        )

        # Try to get feature names
        try:
            feature_names = prep.get_feature_names_out()
        except:
            feature_names = [f"f_{i}" for i in range(X_transformed.shape[1])]

        # SHAP explainer (tree-safe)
        explainer = shap.Explainer(model, X_transformed)

        shap_values = explainer(X_transformed)

        log("SHAP summary plot generating...")

        shap.summary_plot(shap_values, X_transformed, feature_names=feature_names)

        # -------------------------
        # SHAP threshold analysis
        # -------------------------

        log_section("SHAP THRESHOLD ANALYSIS")

        threshold_df = shap_thresholds_with_interpretation(
            X_transformed,
            shap_values.values,
            feature_names,
            top_n=10
        )

        print(threshold_df.to_string(index=False))

        log_section("THRESHOLD ANALYSIS (SHAP + BINNING + PDP)")

        top_feature = threshold_df.iloc[0]["feature"]

        idx = list(feature_names).index(top_feature)

        x = X_transformed[:, idx]
        y = shap_values.values[:, idx]

        # SHAP threshold already computed

            
        # BINNING
        bin_result = binning_threshold(x, y)
        print(f"Binning threshold region: {bin_result}")

        # PDP
        plot_pdp(model, X_transformed, [idx])

    except Exception as e:
        log(f"SHAP failed: {e}")


    # -------------------------
    # FEATURE RECOMMENDATION TABLE
    # -------------------------
    log_section("FEATURE RECOMMENDATION")

    # get top features from importance
    top_features = [f.split("__")[-1] for f in feature_names[:10]]

    # IMPORTANT: use ORIGINAL X_val (not transformed)
    recommendation_df = generate_feature_recommendations(
        model=best_model,
        X=X_val,
        top_features=top_features,
        n_bins=10
    )

    print(recommendation_df.to_string(index=False))

    # -------------------------
    # 12. FINAL SUMMARY
    # -------------------------
    log_section("12. FINAL SUMMARY")

    log(f"Total runtime: {time.time() - start_time:.2f}s")

    return {
        "results_table": results_df,
        "best_model": best_model,
        "ensemble_weights": weights
    }

# %% [markdown]
# ## SUNSCREEN MAIN PIPELINE

# %%
df_sunscreen = df_sunscreen.drop(columns=["seller_joined_date", "discount"], errors="ignore")
run_pipeline(df_sunscreen)
# Out:
# ==================================================
# [STAGE] 1. DATA SPLIT
# ==================================================
# [INFO] Train shape: (2156, 44)
# [INFO] Validation shape: (540, 44)
# [INFO] Test shape: (675, 44)
#
# ==================================================
# [STAGE] 2. TARGET ENGINE (PCA + BOOTSTRAP)
# ==================================================
# [INFO] PCA Weights: [0.52312478 0.81428238]
# [INFO] Weight STD: [0.20120685 0.15099827]
#
# ==================================================
# [STAGE] PCA NORMALIZED WEIGHTS (%)
# ==================================================
# [INFO] z_sold: 39.11% ± 15.04%
# [INFO] z_rating_credibility: 60.89% ± 11.29%
#
# PCA Weight Summary Table:
#            component  weight_raw  weight_std  weight_pct   std_pct
#               z_sold    0.523125    0.201207   39.114848 15.044547
# z_rating_credibility    0.814282    0.150998   60.885152 11.290374
#
# ==================================================
# [STAGE] 3. FEATURE SELECTION
# ==================================================
# [INFO] Selected features: 31
#
# ==================================================
# [STAGE] 4. FEATURE TYPE DETECTION
# ==================================================
# [INFO] # Numeric: 22
# [INFO] # Categorical: 6
# [INFO] # Binary: 3
#
# ==================================================
# [STAGE] 5. BUILD PIPELINES
# ==================================================
#
# [DEBUG] Linear features:
# ['log_final_price', 'log_initial_price', 'log_stock', 'log_favorite', 'log_seller_followers', 'log_seller_products', 'log_discount', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply']
#
# [DEBUG] Tree features:
# ['final_price', 'initial_price', 'stock', 'favorite', 'seller_followers', 'seller_products', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply', 'variations_count']
#
# ==================================================
# [STAGE] 6. MODEL REGISTRY
# ==================================================
# [INFO] Preprocessors assigned for 11 models
#
# ==================================================
# [STAGE] 7. STAGE 1 SEARCH
# ==================================================
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2116
# [LightGBM] [Info] Number of data points in the train set: 1724, number of used features: 49
# [LightGBM] [Info] Start training from score -0.001998
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000312 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2112
# [LightGBM] [Info] Number of data points in the train set: 1725, number of used features: 49
# [LightGBM] [Info] Start training from score -0.006416
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2121
# [LightGBM] [Info] Number of data points in the train set: 1725, number of used features: 49
# [LightGBM] [Info] Start training from score -0.002444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2118
# [LightGBM] [Info] Number of data points in the train set: 1725, number of used features: 49
# [LightGBM] [Info] Start training from score -0.020549
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000331 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2118
# [LightGBM] [Info] Number of data points in the train set: 1725, number of used features: 49
# [LightGBM] [Info] Start training from score -0.012215
#
# ==================================================
# [STAGE] STAGE 1 MODEL PERFORMANCE TABLE
# ==================================================
#             model  cv_rmse_mean  cv_rmse_sd  cv_mae_mean  cv_r2_mean
#       extra_trees      0.508983    0.065667     0.278314    0.754404
#          catboost      0.509663    0.053101     0.264110    0.756299
# ## SANDAL MAIN PIPELINE

# %%
df_sandal = df_sandal.drop(columns=["seller_joined_date", "breadcrumb", "discount"], errors="ignore")
run_pipeline(df_sandal)
# Out:
# ==================================================
# [STAGE] 1. DATA SPLIT
# ==================================================
# [INFO] Train shape: (6400, 43)
# [INFO] Validation shape: (1600, 43)
# [INFO] Test shape: (2000, 43)
#
# ==================================================
# [STAGE] 2. TARGET ENGINE (PCA + BOOTSTRAP)
# ==================================================
# [INFO] PCA Weights: [0.7143042  0.69912474]
# [INFO] Weight STD: [0.02211294 0.02247503]
#
# ==================================================
# [STAGE] PCA NORMALIZED WEIGHTS (%)
# ==================================================
# [INFO] z_sold: 50.54% ± 1.56%
# [INFO] z_rating_credibility: 49.46% ± 1.59%
#
# PCA Weight Summary Table:
#            component  weight_raw  weight_std  weight_pct  std_pct
#               z_sold    0.714304    0.022113   50.536973 1.564489
# z_rating_credibility    0.699125    0.022475   49.463027 1.590107
#
# ==================================================
# [STAGE] 3. FEATURE SELECTION
# ==================================================
# [INFO] Selected features: 30
#
# ==================================================
# [STAGE] 4. FEATURE TYPE DETECTION
# ==================================================
# [INFO] # Numeric: 18
# [INFO] # Categorical: 9
# [INFO] # Binary: 3
#
# ==================================================
# [STAGE] 5. BUILD PIPELINES
# ==================================================
#
# [DEBUG] Linear features:
# ['log_final_price', 'log_seller_products', 'log_seller_followers', 'log_initial_price', 'log_stock', 'log_favorite', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply', 'variations_count']
#
# [DEBUG] Tree features:
# ['final_price', 'seller_products', 'seller_followers', 'initial_price', 'stock', 'favorite', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply', 'variations_count']
#
# ==================================================
# [STAGE] 6. MODEL REGISTRY
# ==================================================
# [INFO] Preprocessors assigned for 11 models
#
# ==================================================
# [STAGE] 7. STAGE 1 SEARCH
# ==================================================
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005926 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2272
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score 0.003029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000398 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2276
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score -0.004197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000329 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score 0.016817
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000492 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2284
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score -0.000931
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2282
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 58
# [LightGBM] [Info] Start training from score 0.004079
#
# ==================================================
# [STAGE] STAGE 1 MODEL PERFORMANCE TABLE
# ==================================================
#             model  cv_rmse_mean  cv_rmse_sd  cv_mae_mean  cv_r2_mean
#          catboost      0.638322    0.020861     0.446769    0.733620
#          lightgbm      0.649967    0.027034     0.454951    0.723897
#           xgboost      0.684017    0.029019     0.470367    0.694609
#       extra_trees      0.687062    0.026700     0.472720    0.692106
#     random_forest      0.691988    0.029708     0.478103    0.687612
#               svr      0.793399    0.028149     0.527472    0.588485
#               knn      0.861690    0.032227     0.592115    0.514355
#             ridge      0.933033    0.037049     0.689461    0.432089
# linear_regression      0.934284    0.037099     0.690163    0.430586
#       elastic_net      1.230891    0.048606     0.930465    0.012401
#             lasso      1.239034    0.045808     0.935522   -0.000886
# [I 2026-04-11 13:54:13,170] A new study created in memory with name: no-name-ed4d8952-1854-407f-8d61-afd8ca680af1
# [INFO] Top models: ['catboost', 'lightgbm', 'xgboost']
#
# ==================================================
# [STAGE] STAGE 2: HYPERPARAMETER TUNING
# ==================================================
# [INFO] Tuning model: catboost
# [I 2026-04-11 13:54:15,001] Trial 0 finished with value: 0.8975213600783706 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8975213600783706.
# [I 2026-04-11 13:54:16,732] Trial 1 finished with value: 0.8975213600783706 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8975213600783706.
# [I 2026-04-11 13:54:18,552] Trial 2 finished with value: 0.8975213600783706 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8975213600783706.
# [I 2026-04-11 13:54:20,381] Trial 3 finished with value: 0.8975213600783706 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8975213600783706.
# [I 2026-04-11 13:54:22,177] Trial 4 finished with value: 0.8975213600783706 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8975213600783706.
# [I 2026-04-11 13:54:23,968] Trial 5 finished with value: 0.8975213600783706 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8975213600783706.
# [I 2026-04-11 13:54:25,774] Trial 6 finished with value: 0.8975213600783706 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8975213600783706.
# [I 2026-04-11 13:54
bm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2272
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score 0.003029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000461 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2276
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score -0.004197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000420 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score 0.016817
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000396 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2284
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score -0.000931
# [I 2026-04-11 13:57:34,670] Trial 0 finished with value: 0.7974873628818904 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.7974873628818904.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000575 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2282
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 58
# [LightGBM] [Info] Start training from score 0.004079
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000456 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2272
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score 0.003029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2276
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score -0.004197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000494 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score 0.016817
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000448 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2284
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score -0.000931
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000449 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2282
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 58
# [LightGBM] [Info] Start training from score 0.004079
# [I 2026-04-11 13:57:35,706] Trial 1 finished with value: 0.7974873628818904 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.7974873628818904.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000443 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2272
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score 0.003029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2276
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score -0.004197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000444 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score 0.016817
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000446 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2284
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score -0.000931
# [I 2026-04-11 13:57:36,651] Trial 2 finished with value: 0.7974873628818904 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.7974873628818904.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000458 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2282
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 58
# [LightGBM] [Info] Start training from score 0.004079
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000518 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2272
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score 0.003029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000444 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2276
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score -0.004197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000442 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score 0.016817
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000430 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2284
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score -0.000931
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000453 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2282
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 58
# [LightGBM] [Info] Start training from score 0.004079
# [I 2026-04-11 13:57:37,617] Trial 3 finished with value: 0.7974873628818904 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.7974873628818904.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000471 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2272
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score 0.003029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000382 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2276
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score -0.004197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000440 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score 0.016817
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000449 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2284
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 57
# [LightGBM] [Info] Start training from score -0.000931
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000457 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2282
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 58
# [LightGBM] [Info] Start training from score 0.004079
# [I 2026-04-11 13:57:38,583] Trial 4 finished with value: 0.7974873628818904 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.7974873628818904.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000602 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2272
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score 0.003029
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000453 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2276
# [LightGBM] [Info] Number of data points in the train set: 5120, number of used features: 56
# [LightGBM] [Info] Start training from score -0.004197
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000468 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2278
# ...
# [I 2026-04-11 14:01:03,152] Trial 99 finished with value: 0.8814577344426405 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.6070331443430721}. Best is trial 44 with value: 0.8806773923718382.
# [INFO] Best params for xgboost: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.6020854658497994}
#
# Tuning Summary:
#   model  n_trials                                                                                   best_params
# xgboost       100 {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.6020854658497994}
#
# ==================================================
# [STAGE] 8. TRAIN FINAL MODELS
# ==================================================
# [INFO] Training: catboost
# [INFO] Training: lightgbm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000595 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2295
# [LightGBM] [Info] Number of data points in the train set: 6400, number of used features: 58
# [LightGBM] [Info] Start training from score 0.003759
# [INFO] Training: xgboost
#
# ==================================================
# [STAGE] MODEL IMPROVEMENT (STAGE 1 vs STAGE 2)
# ==================================================
#    model  stage1_rmse  stage1_mae  stage1_r2  stage2_rmse  stage2_mae  stage2_r2  rmse_improvement  mae_improvement  r2_improvement
# catboost     0.638322    0.446769   0.733620     0.613698    0.436603   0.745313          0.024624         0.010166        0.011693
# lightgbm     0.649967    0.454951   0.723897     0.637679    0.447905   0.725019          0.012288         0.007046        0.001122
#  xgboost     0.684017    0.470367   0.694609     0.645404    0.455568   0.718316          0.038613         0.014798        0.023707
#
# ==================================================
# [STAGE] TOP MODELS FEATURE IMPORTANCE
# ==================================================
# ==================================================
# [STAGE] 9. ENSEMBLE
# ==================================================
#
# ==================================================
# [STAGE] ENSEMBLE FEATURE IMPORTANCE
# ==================================================
#                                feature  importance
#               num__discount_percentage  122.717167
#                     num__initial_price  117.438018
#                   num__seller_products  110.649922
#                  num__seller_followers  104.751958
#                             num__stock   93.043895
# num__seller_chats_responded_percentage   85.573790
#                     num__seller_rating   71.512616
#                          num__favorite   57.084679
#                       num__final_price   54.057390
#                  num__variations_count   45.037739
# ==================================================
# [STAGE] 10. MODEL PERFORMANCE TABLE
# ==================================================
#    model     rmse      mae       r2
# ensemble 0.611233 0.432884 0.747354
# catboost 0.613698 0.436603 0.745313
# lightgbm 0.637679 0.447905 0.725019
#  xgboost 0.645404 0.455568 0.718316
# [INFO] Best model: catboost
#
# ==================================================
# [STAGE] 11. SHAP ANALYSIS
# ==================================================
#  98%|===================| 979/1000 [00:37<00:00]
# [INFO] SHAP summary plot generating...
# ==================================================
# [STAGE] SHAP THRESHOLD ANALYSIS
# ==================================================
#                                feature  threshold_log  threshold_real                             interpretation                                                        insight
#               num__discount_percentage      84.615385       84.615385                discount_percentage > 84.62 Above this threshold → strong positive impact on success score
#                     num__initial_price   13000.000000    13000.000000                   initial_price > 13000.00 Above this threshold → strong positive impact on success score
#                  num__seller_followers       0.000000        0.000000                    seller_followers > 0.00 Above this threshold → strong positive impact on success score
#                             num__stock       0.000000        0.000000                               stock > 0.00 Above this threshold → strong positive impact on success score
#                  num__variations_count       0.000000        0.000000                    variations_count > 0.00 Above this threshold → strong positive impact on success score
#                   num__seller_products       6.000000        6.000000                     seller_products > 6.00 Above this threshold → strong positive impact on success score
# num__seller_chats_responded_percentage     100.000000      100.000000 seller_chats_responded_percentage > 100.00 Above this threshold → strong positive impact on success score
#                          num__favorite       0.000000        0.000000                            favorite > 0.00 Above this threshold → strong positive impact on success score
#                       num__final_price    2000.000000     2000.000000                      final_price > 2000.00 Above this threshold → strong positive impact on success score
#                     num__seller_rating       1.630000        1.630000                       seller_rating > 1.63 Above this threshold → strong positive impact on success score
#
# ==================================================
# [STAGE] THRESHOLD ANALYSIS (SHAP + BINNING + PDP)
# ==================================================
# Binning threshold region: (-590.025, -72.274]
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1290: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1290: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1291: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1291: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1292: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1292: RuntimeWarning: invalid value encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1298: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1307: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_0
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1314: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_n
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1314197550.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby("bin")["y"].mean()
# ==================================================
# [STAGE] FEATURE RECOMMENDATION
# ==================================================
#                           feature  current_typical_value recommended_target_or_range  best_predicted_bin_mean                                    note
#                       final_price             49711.8313      2.603e+05 to 1.216e+06                 0.551669 Optimal range based on model prediction
#                   seller_products               246.0000                  186 to 246                 0.414859 Optimal range based on model prediction
#                  seller_followers            109372.6081      2.774e+05 to 4.069e+05                 1.147174 Optimal range based on model prediction
#                     initial_price             80000.0000               5000 to 3e+04                 0.269174 Optimal range based on model prediction
#                             stock                75.0000                 75 to 183.4                 0.324397 Optimal range based on model prediction
#                          favorite                67.8266          356.5 to 2.156e+04                 0.869127 Optimal range based on model prediction
#                     seller_rating                 4.8100                4.85 to 4.87                 0.286518 Optimal range based on model prediction
# seller_chats_responded_percentage                93.6647                98.63 to 100                 0.671681 Optimal range based on model prediction
#            seller_chat_time_reply                 1.0000                  0.019 to 1                -0.014167 Optimal range based on model prediction
#                  variations_count                 9.0000                    13 to 50                 0.358811 Optimal range based on model prediction
#
# ==================================================
# [STAGE] 12. FINAL SUMMARY
# ==================================================
# [INFO] Total runtime: 737.95s
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# {'results_table':       model      rmse       mae        r2
#  3  ensemble  0.611233  0.432884  0.747354
#  0  catboost  0.613698  0.436603  0.745313
#  1  lightgbm  0.637679  0.447905  0.725019
#  2   xgboost  0.645404  0.455568  0.718316,
#  'best_model': Pipeline(steps=[('prep',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(strategy='median'))]),
#                                                    ['final_price',
#                                                     'seller_products',
#                                                     'seller_followers',
#                                                     'initial_price', 'stock',
#                                                     'favorite', 'seller_rating',
#                                                     'seller_chats_responded_percentage',
#                                                     'seller_chat_time_reply',
#                                                     'variations_count',
#                                                     'image_count',
#                                                     'discount_percentage']),
#                                                   ('cat',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(fill_value='missing',
#                                                                                   strategy='constant')),
#                                                                    ('onehot',
#                                                                     OneHotEncoder(handle_unknown='ignore'))]),
#                                                    ['brand', 'shipped_from',
#                                                     'heel_height', 'material',
#                                                     'toe_type',
#                                                     'country_of_origin',
#                                                     'shoe_model',
#                                                     'fastener_type',
#                                                     'occasion'])])),
#                  ('model',
#                   <catboost.core.CatBoostRegressor object at 0x0000027C27D56480>)]),
#  'ensemble_weights': array([0.34325728, 0.33034831, 0.32639442])}

# %% [markdown]
# ## WALLET MAIN PIPELINE

# %%
df_wallet = df_wallet.drop(columns=["seller_joined_date", "breadcrumb", "discount", "log_gmv"], errors="ignore")
run_pipeline(df_wallet)
# Out:
# ==================================================
# [STAGE] 1. DATA SPLIT
# ==================================================
# [INFO] Train shape: (2656, 48)
# [INFO] Validation shape: (664, 48)
# [INFO] Test shape: (831, 48)
#
# ==================================================
# [STAGE] 2. TARGET ENGINE (PCA + BOOTSTRAP)
# ==================================================
# [INFO] PCA Weights: [0.69841669 0.71490038]
# [INFO] Weight STD: [0.02399493 0.02357584]
#
# ==================================================
# [STAGE] PCA NORMALIZED WEIGHTS (%)
# ==================================================
# [INFO] z_sold: 49.42% ± 1.70%
# [INFO] z_rating_credibility: 50.58% ± 1.67%
#
# PCA Weight Summary Table:
#            component  weight_raw  weight_std  weight_pct  std_pct
#               z_sold    0.698417    0.023995   49.416844 1.697774
# z_rating_credibility    0.714900    0.023576   50.583156 1.668121
#
# ==================================================
# [STAGE] 3. FEATURE SELECTION
# ==================================================
# [INFO] Selected features: 35
#
# ==================================================
# [STAGE] 4. FEATURE TYPE DETECTION
# ==================================================
# [INFO] # Numeric: 19
# [INFO] # Categorical: 13
# [INFO] # Binary: 3
#
# ==================================================
# [STAGE] 5. BUILD PIPELINES
# ==================================================
#
# [DEBUG] Linear features:
# ['log_favorite', 'log_final_price', 'log_initial_price', 'log_stock', 'log_seller_followers', 'log_seller_products', 'log_discount', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply']
#
# [DEBUG] Tree features:
# ['favorite', 'final_price', 'initial_price', 'stock', 'seller_followers', 'seller_products', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply', 'variations_count']
#
# ==================================================
# [STAGE] 6. MODEL REGISTRY
# ==================================================
# [INFO] Preprocessors assigned for 11 models
#
# ==================================================
# [STAGE] 7. STAGE 1 SEARCH
# ==================================================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000265 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2124, number of used features: 66
# [LightGBM] [Info] Start training from score -0.013603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000230 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1998
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.014260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000228 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.029957
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000296 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2006
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.022105
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000220 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2002
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.032975
#
# ==================================================
# [STAGE] STAGE 1 MODEL PERFORMANCE TABLE
# ==================================================
#             model  cv_rmse_mean  cv_rmse_sd  cv_mae_mean  cv_r2_mean
#          catboost      0.753999    0.044382     0.453066    0.619665
#          lightgbm      0.759258    0.052060     0.455501    0.614399
#       extra_trees      0.780675    0.052448     0.454701    0.592461
#     random_forest      0.785324    0.037503     0.453151    0.587742
#           xgboost      0.788095    0.053750     0.466437    0.583043
#               knn      0.886571    0.057520     0.555434    0.474465
#               svr      0.893970    0.052953     0.486833    0.466859
#             ridge      0.930255    0.049227     0.647467    0.422461
# linear_regression      0.932404    0.049182     0.649164    0.419792
#       elastic_net      1.177907    0.049581     0.907626    0.073864
#             lasso      1.224478    0.048004     0.962415   -0.001033
# [I 2026-04-11 14:03:36,222] A new study created in memory with name: no-name-7c080f36-e608-4f9a-8bb6-ba23c670f11c
# [INFO] Top models: ['catboost', 'lightgbm', 'extra_trees']
#
# ==================================================
# [STAGE] STAGE 2: HYPERPARAMETER TUNING
# ==================================================
# [INFO] Tuning model: catboost
# [I 2026-04-11 14:03:37,838] Trial 0 finished with value: 0.9189214743872011 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.9189214743872011.
# [I 2026-04-11 14:03
# 193:	learn: 0.8951733	total: 259ms	remaining: 8ms
# 194:	learn: 0.8946619	total: 260ms	remaining: 6.67ms
# 195:	learn: 0.8940187	total: 261ms	remaining: 5.34ms
# 196:	learn: 0.8934858	total: 263ms	remaining: 4ms
# 197:	learn: 0.8927397	total: 264ms	remaining: 2.67ms
# 198:	learn: 0.8920465	total: 266ms	remaining: 1.33ms
# 199:	learn: 0.8915910	total: 267ms	remaining: 0us
# [INFO] Tuning model: lightgbm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2124, number of used features: 66
# [LightGBM] [Info] Start training from score -0.013603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1998
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.014260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000288 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.029957
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000280 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2006
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.022105
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000293 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2002
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.032975
# [I 2026-04-11 14:06:41,689] Trial 0 finished with value: 0.8231704600635348 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8231704600635348.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000273 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2124, number of used features: 66
# [LightGBM] [Info] Start training from score -0.013603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000286 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1998
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.014260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.029957
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000321 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2006
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.022105
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000285 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2002
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.032975
# [I 2026-04-11 14:06:42,568] Trial 1 finished with value: 0.8231704600635348 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8231704600635348.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2124, number of used features: 66
# [LightGBM] [Info] Start training from score -0.013603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000279 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1998
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.014260
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000784 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.029957
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000275 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2006
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.022105
# [I 2026-04-11 14:06:43,368] Trial 2 finished with value: 0.8231704600635348 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8231704600635348.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000535 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2002
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.032975
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000246 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2124, number of used features: 66
# [LightGBM] [Info] Start training from score -0.013603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000238 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1998
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.014260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000282 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.029957
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2006
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.022105
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000283 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2002
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.032975
# [I 2026-04-11 14:06:44,088] Trial 3 finished with value: 0.8231704600635348 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8231704600635348.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2124, number of used features: 66
# [LightGBM] [Info] Start training from score -0.013603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000269 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1998
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.014260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.029957
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000263 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2006
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.022105
# [I 2026-04-11 14:06:44,829] Trial 4 finished with value: 0.8231704600635348 and parameters: {'n_estimators': 200, 'num_leaves': 20, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8231704600635348.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000255 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2002
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 67
# [LightGBM] [Info] Start training from score -0.032975
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000278 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# [LightGBM] [Info] Number of data points in the train set: 2124, number of used features: 66
# [LightGBM] [Info] Start training from score -0.013603
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000279 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1998
# [LightGBM] [Info] Number of data points in the train set: 2125, number of used features: 66
# [LightGBM] [Info] Start training from score -0.014260
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000280 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2011
# ...
# [I 2026-04-11 14:16:53,144] Trial 99 finished with value: 0.9053087869499791 and parameters: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 2}. Best is trial 40 with value: 0.9027101698519753.
# [INFO] Best params for extra_trees: {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 2}
#
# Tuning Summary:
#       model  n_trials                                                   best_params
# extra_trees       100 {'n_estimators': 100, 'max_depth': 5, 'min_samples_split': 2}
#
# ==================================================
# [STAGE] 8. TRAIN FINAL MODELS
# ==================================================
# [INFO] Training: catboost
# [INFO] Training: lightgbm
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000298 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2033
# [LightGBM] [Info] Number of data points in the train set: 2656, number of used features: 69
# [LightGBM] [Info] Start training from score -0.022581
# [INFO] Training: extra_trees
#
# ==================================================
# [STAGE] MODEL IMPROVEMENT (STAGE 1 vs STAGE 2)
# ==================================================
#       model  stage1_rmse  stage1_mae  stage1_r2  stage2_rmse  stage2_mae  stage2_r2  rmse_improvement  mae_improvement  r2_improvement
#    catboost     0.753999    0.453066   0.619665     0.799737    0.467221   0.583104         -0.045737        -0.014154       -0.036561
#    lightgbm     0.759258    0.455501   0.614399     0.792356    0.460693   0.590764         -0.033098        -0.005192       -0.023635
# extra_trees     0.780675    0.454701   0.592461     0.808144    0.456172   0.574293         -0.027469        -0.001472       -0.018168
#
# ==================================================
# [STAGE] TOP MODELS FEATURE IMPORTANCE
# ==================================================
# ==================================================
# [STAGE] 9. ENSEMBLE
# ==================================================
#
# ==================================================
# [STAGE] ENSEMBLE FEATURE IMPORTANCE
# ==================================================
#                                feature  importance
#                          num__favorite  137.915110
#                  num__seller_followers  123.564269
#                             num__stock  114.466036
#                     num__initial_price  101.580918
#                   num__seller_products   92.243012
#                       num__final_price   88.994899
#               num__discount_percentage   77.054825
#                     num__seller_rating   50.517019
#                  num__variations_count   46.746109
# num__seller_chats_responded_percentage   31.088118
# ==================================================
# [STAGE] 10. MODEL PERFORMANCE TABLE
# ==================================================
#       model     rmse      mae       r2
#    ensemble 0.775420 0.443160 0.608071
#    lightgbm 0.792356 0.460693 0.590764
#    catboost 0.799737 0.467221 0.583104
# extra_trees 0.808144 0.456172 0.574293
# [INFO] Best model: lightgbm
#
# ==================================================
# [STAGE] 11. SHAP ANALYSIS
# ==================================================
# [INFO] SHAP summary plot generating...
# ==================================================
# [STAGE] SHAP THRESHOLD ANALYSIS
# ==================================================
#                     feature  threshold_log  threshold_real                                       interpretation                                                        insight
#               num__favorite           0.00            0.00                                      favorite > 0.00 Above this threshold → strong positive impact on success score
#       num__seller_followers          14.00           14.00                             seller_followers > 14.00 Above this threshold → strong positive impact on success score
#                  num__stock           0.00            0.00                                         stock > 0.00 Above this threshold → strong positive impact on success score
#        num__seller_products           8.00            8.00                               seller_products > 8.00 Above this threshold → strong positive impact on success score
#            num__final_price        7888.00         7888.00                                final_price > 7888.00 Above this threshold → strong positive impact on success score
#          num__initial_price        7999.00         7999.00                              initial_price > 7999.00 Above this threshold → strong positive impact on success score
#    num__discount_percentage           0.00            0.00                           discount_percentage > 0.00 Above this threshold → strong positive impact on success score
#       num__variations_count           0.00            0.00                              variations_count > 0.00 Above this threshold → strong positive impact on success score
#          num__seller_rating           4.59            4.59                                 seller_rating > 4.59 Above this threshold → strong positive impact on success score
# cat__leather_texture_Smooth            NaN             NaN Categorical feature — interpret via presence/absence                  This category impacts prediction when present
#
# ==================================================
# [STAGE] THRESHOLD ANALYSIS (SHAP + BINNING + PDP)
# ==================================================
# Binning threshold region: (380.3, 997.0]
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1290: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1290: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1291: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1291: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1292: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1292: RuntimeWarning: invalid value encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1298: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1307: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_0
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1314: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_n
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1314197550.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby("bin")["y"].mean()
# ==================================================
# [STAGE] FEATURE RECOMMENDATION
# ==================================================
#                           feature  current_typical_value recommended_target_or_range  best_predicted_bin_mean                                    note
#                          favorite                  26.00                380.3 to 997                 1.079111 Optimal range based on model prediction
#                       final_price               69000.00             3999 to 2.3e+04                 0.808272 Optimal range based on model prediction
#                     initial_price              128000.00            7999 to 4.32e+04                 0.745458 Optimal range based on model prediction
#                             stock                  84.50            2179 to 2.49e+04                 1.101735 Optimal range based on model prediction
#                  seller_followers               32500.00      3.841e+05 to 6.954e+05                 1.002067 Optimal range based on model prediction
#                   seller_products                 285.00                 679 to 1552                 0.431480 Optimal range based on model prediction
#                     seller_rating                   4.85               1.349 to 4.74                 0.476906 Optimal range based on model prediction
# seller_chats_responded_percentage                  94.00                   99 to 100                 0.473546 Optimal range based on model prediction
#            seller_chat_time_reply                   1.00                  0.499 to 1                 0.016751 Optimal range based on model prediction
#                  variations_count                   5.00                     9 to 49                 0.495083 Optimal range based on model prediction
#
# ==================================================
# [STAGE] 12. FINAL SUMMARY
# ==================================================
# [INFO] Total runtime: 923.95s
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# {'results_table':          model      rmse       mae        r2
#  3     ensemble  0.775420  0.443160  0.608071
#  1     lightgbm  0.792356  0.460693  0.590764
#  0     catboost  0.799737  0.467221  0.583104
#  2  extra_trees  0.808144  0.456172  0.574293,
#  'best_model': Pipeline(steps=[('prep',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(strategy='median'))]),
#                                                    ['favorite', 'final_price',
#                                                     'initial_price', 'stock',
#                                                     'seller_followers',
#                                                     'seller_products',
#                                                     'seller_rating',
#                                                     'seller_chats_responded_percentage',
#                                                     'seller_chat_time_reply',
#                                                     'variations_count',
#                                                     'image_count',
#                                                     'discount_percentage']),
#                                                   ('c...
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(fill_value='missing',
#                                                                                   strategy='constant')),
#                                                                    ('onehot',
#                                                                     OneHotEncoder(handle_unknown='ignore'))]),
#                                                    ['brand', 'motif',
#                                                     'warranty_type', 'material',
#                                                     'warranty_duration',
#                                                     'country_of_origin',
#                                                     'closure_type', 'card_slots',
#                                                     'leather_texture',
#                                                     'leather_finish',
#                                                     'leather_type',
#                                                     'shipped_from_region',
#                                                     'wallet_type'])])),
#                  ('model', LGBMRegressor())]),
#  'ensemble_weights': array([0.33345432, 0.33656038, 0.3299853 ])}

# %% [markdown]
# ## PAN MAIN PIPELINE

# %%
df_pan = df_pan.drop(columns=["seller_joined_date", "discount"], errors="ignore")
run_pipeline(df_pan)
# Out:
# ==================================================
# [STAGE] 1. DATA SPLIT
# ==================================================
# [INFO] Train shape: (2912, 42)
# [INFO] Validation shape: (728, 42)
# [INFO] Test shape: (911, 42)
#
# ==================================================
# [STAGE] 2. TARGET ENGINE (PCA + BOOTSTRAP)
# ==================================================
# [INFO] PCA Weights: [0.78266051 0.56222328]
# [INFO] Weight STD: [0.17175377 0.20456823]
#
# ==================================================
# [STAGE] PCA NORMALIZED WEIGHTS (%)
# ==================================================
# [INFO] z_sold: 58.20% ± 12.77%
# [INFO] z_rating_credibility: 41.80% ± 15.21%
#
# PCA Weight Summary Table:
#            component  weight_raw  weight_std  weight_pct   std_pct
#               z_sold    0.782661    0.171754   58.195401 12.770901
# z_rating_credibility    0.562223    0.204568   41.804599 15.210848
#
# ==================================================
# [STAGE] 3. FEATURE SELECTION
# ==================================================
# [INFO] Selected features: 29
#
# ==================================================
# [STAGE] 4. FEATURE TYPE DETECTION
# ==================================================
# [INFO] # Numeric: 19
# [INFO] # Categorical: 8
# [INFO] # Binary: 2
#
# ==================================================
# [STAGE] 5. BUILD PIPELINES
# ==================================================
#
# [DEBUG] Linear features:
# ['log_final_price', 'log_initial_price', 'log_stock', 'log_favorite', 'log_seller_followers', 'log_seller_products', 'log_discount', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply']
#
# [DEBUG] Tree features:
# ['final_price', 'initial_price', 'stock', 'favorite', 'seller_followers', 'seller_products', 'seller_rating', 'seller_chats_responded_percentage', 'seller_chat_time_reply', 'variations_count']
#
# ==================================================
# [STAGE] 6. MODEL REGISTRY
# ==================================================
# [INFO] Preprocessors assigned for 11 models
#
# ==================================================
# [STAGE] 7. STAGE 1 SEARCH
# ==================================================
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000220 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2308
# [LightGBM] [Info] Number of data points in the train set: 2329, number of used features: 62
# [LightGBM] [Info] Start training from score 0.006950
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000219 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2305
# [LightGBM] [Info] Number of data points in the train set: 2329, number of used features: 61
# [LightGBM] [Info] Start training from score 0.033589
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2313
# [LightGBM] [Info] Number of data points in the train set: 2330, number of used features: 65
# [LightGBM] [Info] Start training from score 0.022571
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000217 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2309
# [LightGBM] [Info] Number of data points in the train set: 2330, number of used features: 63
# [LightGBM] [Info] Start training from score 0.014369
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000212 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2311
# [LightGBM] [Info] Number of data points in the train set: 2330, number of used features: 63
# [LightGBM] [Info] Start training from score 0.005302
#
# ==================================================
# [STAGE] STAGE 1 MODEL PERFORMANCE TABLE
# ==================================================
#             model  cv_rmse_mean  cv_rmse_sd  cv_mae_mean  cv_r2_mean
#          catboost      0.687205    0.236556     0.226598    0.658837
#     random_forest      0.709360    0.196612     0.240406    0.633914
#           xgboost      0.790303    0.224529     0.236533    0.524559
#          lightgbm      0.814222    0.256512     0.264330    0.539505
#       extra_trees      0.893294    0.300106     0.262527    0.431899
#               knn      0.900294    0.271304     0.291059    0.432161
#               svr      0.920252    0.286947     0.263073    0.415556
#             ridge      0.981917    0.279978     0.434432    0.328257
# linear_regression      0.987223    0.278916     0.443521    0.320387
#       elastic_net      1.135686    0.280435     0.522849    0.088602
#             lasso      1.186090    0.270124     0.578788   -0.002999
# [I 2026-04-11 14:18:51,413] A new study created in memory with name: no-name-143105be-02e8-46cf-8343-a30f91f2879a
# [INFO] Top models: ['catboost', 'random_forest', 'xgboost']
#
# ==================================================
# [STAGE] STAGE 2: HYPERPARAMETER TUNING
# ==================================================
# [INFO] Tuning model: catboost
# [I 2026-04-11 14:18:52,878] Trial 0 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:18:54,411] Trial 1 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:18:55,976] Trial 2 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:18:57,508] Trial 3 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:18:59,057] Trial 4 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:00,569] Trial 5 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:02,121] Trial 6 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:03,799] Trial 7 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:05,431] Trial 8 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:07,017] Trial 9 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:08,582] Trial 10 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:10,167] Trial 11 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:11,729] Trial 12 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:13,311] Trial 13 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:14,889] Trial 14 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:16,476] Trial 15 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:18,135] Trial 16 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:19,706] Trial 17 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:21,366] Trial 18 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:22,989] Trial 19 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:24,597] Trial 20 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:26,201] Trial 21 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:27,800] Trial 22 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:29,398] Trial 23 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:31,012] Trial 24 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:32,596] Trial 25 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:34,161] Trial 26 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:35,776] Trial 27 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:37,442] Trial 28 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:39,056] Trial 29 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:40,614] Trial 30 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:42,450] Trial 31 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:44,236] Trial 32 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:46,018] Trial 33 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:47,791] Trial 34 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:49,565] Trial 35 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:51,397] Trial 36 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:53,204] Trial 37 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:54,993] Trial 38 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:56,722] Trial 39 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:19:58,441] Trial 40 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:00,273] Trial 41 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:02,021] Trial 42 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:03,853] Trial 43 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:05,614] Trial 44 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:07,282] Trial 45 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:09,049] Trial 46 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:10,795] Trial 47 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:12,529] Trial 48 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:14,259] Trial 49 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:16,072] Trial 50 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:17,997] Trial 51 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:19,834] Trial 52 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:21,702] Trial 53 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:23,660] Trial 54 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:25,855] Trial 55 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:27,970] Trial 56 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:29,966] Trial 57 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:31,915] Trial 58 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:33,678] Trial 59 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:35,477] Trial 60 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:37,342] Trial 61 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:39,138] Trial 62 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:40,917] Trial 63 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:42,657] Trial 64 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:44,453] Trial 65 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:46,212] Trial 66 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:47,950] Trial 67 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:49,681] Trial 68 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:51,433] Trial 69 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:53,204] Trial 70 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:54,990] Trial 71 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14:20:56,843] Trial 72 finished with value: 0.8295613208082295 and parameters: {'iterations': 200, 'depth': 4, 'learning_rate': 0.01}. Best is trial 0 with value: 0.8295613208082295.
# [I 2026-04-11 14
and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.6861539985428625}. Best is trial 32 with value: 0.7785807266291449.
# [I 2026-04-11 14:33:00,321] Trial 98 finished with value: 0.7803146358206624 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.6652772996960371}. Best is trial 32 with value: 0.7785807266291449.
# [I 2026-04-11 14:33:01,079] Trial 99 finished with value: 0.7883633570647245 and parameters: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.631556380353755}. Best is trial 32 with value: 0.7785807266291449.
# [INFO] Best params for xgboost: {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.6745878685853305}
#
# Tuning Summary:
#   model  n_trials                                                                                   best_params
# xgboost       100 {'n_estimators': 200, 'max_depth': 3, 'learning_rate': 0.01, 'subsample': 0.6745878685853305}
#
# ==================================================
# [STAGE] 8. TRAIN FINAL MODELS
# ==================================================
# [INFO] Training: catboost
# [INFO] Training: random_forest
# [INFO] Training: xgboost
#
# ==================================================
# [STAGE] MODEL IMPROVEMENT (STAGE 1 vs STAGE 2)
# ==================================================
#         model  stage1_rmse  stage1_mae  stage1_r2  stage2_rmse  stage2_mae  stage2_r2  rmse_improvement  mae_improvement  r2_improvement
#      catboost     0.687205    0.226598   0.658837     0.388639    0.188934   0.735604          0.298567         0.037665        0.076767
# random_forest     0.709360    0.240406   0.633914     0.494472    0.206829   0.571997          0.214888         0.033577       -0.061917
#       xgboost     0.790303    0.236533   0.524559     0.458213    0.213651   0.632466          0.332090         0.022883        0.107907
#
# ==================================================
# [STAGE] TOP MODELS FEATURE IMPORTANCE
# ==================================================
# ==================================================
# [STAGE] 9. ENSEMBLE
# ==================================================
#
# ==================================================
# [STAGE] ENSEMBLE FEATURE IMPORTANCE
# ==================================================
#                          feature  importance
#                    num__favorite   11.058457
#            num__seller_followers    8.596735
#                 num__image_count    4.023603
#               num__initial_price    3.531303
#                       num__stock    2.814408
#                 num__final_price    2.458387
#            num__variations_count    1.022088
#         num__discount_percentage    0.974951
#             num__seller_products    0.913014
# cat__country_of_origin_Indonesia    0.660627
# ==================================================
# [STAGE] 10. MODEL PERFORMANCE TABLE
# ==================================================
#         model     rmse      mae       r2
#      catboost 0.388639 0.188934 0.735604
#      ensemble 0.410661 0.193650 0.704790
#       xgboost 0.458213 0.213651 0.632466
# random_forest 0.494472 0.206829 0.571997
# [INFO] Best model: catboost
#
# ==================================================
# [STAGE] 11. SHAP ANALYSIS
# ==================================================
# 100%|===================| 727/728 [00:19<00:00]
# [INFO] SHAP summary plot generating...
# ==================================================
# [STAGE] SHAP THRESHOLD ANALYSIS
# ==================================================
#                  feature  threshold_log  threshold_real             interpretation                                                        insight
#            num__favorite            0.0             0.0            favorite > 0.00 Above this threshold → strong positive impact on success score
#         num__image_count            1.0             1.0         image_count > 1.00 Above this threshold → strong positive impact on success score
#    num__seller_followers            0.0             0.0    seller_followers > 0.00 Above this threshold → strong positive impact on success score
#         num__final_price        16500.0         16500.0     final_price > 16500.00 Above this threshold → strong positive impact on success score
#       num__initial_price        16500.0         16500.0   initial_price > 16500.00 Above this threshold → strong positive impact on success score
#               num__stock            0.0             0.0               stock > 0.00 Above this threshold → strong positive impact on success score
# num__discount_percentage            0.0             0.0 discount_percentage > 0.00 Above this threshold → strong positive impact on success score
#       num__seller_rating            0.0             0.0       seller_rating > 0.00 Above this threshold → strong positive impact on success score
#     num__seller_products           18.0            18.0    seller_products > 18.00 Above this threshold → strong positive impact on success score
#    num__variations_count            0.0             0.0    variations_count > 0.00 Above this threshold → strong positive impact on success score
#
# ==================================================
# [STAGE] THRESHOLD ANALYSIS (SHAP + BINNING + PDP)
# ==================================================
# Binning threshold region: (128.6, 4938.0]
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1290: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1290: RuntimeWarning: invalid value encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1291: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1291: RuntimeWarning: invalid value encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1292: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1292: RuntimeWarning: invalid value encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1298: RuntimeWarning: invalid value encountered in add
#   out[tuple(slice1)] = a * f[tuple(slice2)] + b * f[tuple(slice3)] + c * f[tuple(slice4)]
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1307: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_0
# c:\Users\Acer\miniconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:1314: RuntimeWarning: divide by zero encountered in scalar divide
#   out[tuple(slice1)] = (f[tuple(slice2)] - f[tuple(slice3)]) / dx_n
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1314197550.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby("bin")["y"].mean()
# ==================================================
# [STAGE] FEATURE RECOMMENDATION
# ==================================================
#                           feature  current_typical_value recommended_target_or_range  best_predicted_bin_mean                                    note
#                       final_price             129850.000      6.108e+04 to 8.898e+04                 0.292623 Optimal range based on model prediction
#                     initial_price             189999.500      3.138e+05 to 4.443e+05                 0.071055 Optimal range based on model prediction
#                             stock                  0.000          265.4 to 1.778e+06                 1.031180 Optimal range based on model prediction
#                          favorite                  0.000               128.6 to 4938                 1.345967 Optimal range based on model prediction
#                  seller_followers               9191.000             -0.001 to 113.1                 0.399407 Optimal range based on model prediction
#                   seller_products                395.000                520.8 to 647                 0.211568 Optimal range based on model prediction
#                     seller_rating                  4.780                4.82 to 4.84                 0.354400 Optimal range based on model prediction
# seller_chats_responded_percentage                 93.000                   99 to 100                 0.078123 Optimal range based on model prediction
#            seller_chat_time_reply                  1.135                0.067 to 0.5                 0.325897 Optimal range based on model prediction
#                  variations_count                  2.000                      4 to 7                 0.035834 Optimal range based on model prediction
#
# ==================================================
# [STAGE] 12. FINAL SUMMARY
# ==================================================
# [INFO] Total runtime: 987.27s
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10780\1362319550.py:24: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   summary = df.groupby("bin")["pred"].agg(["mean"]).reset_index()
# {'results_table':            model      rmse       mae        r2
#  0       catboost  0.388639  0.188934  0.735604
#  3       ensemble  0.410661  0.193650  0.704790
#  2        xgboost  0.458213  0.213651  0.632466
#  1  random_forest  0.494472  0.206829  0.571997,
#  'best_model': Pipeline(steps=[('prep',
#                   ColumnTransformer(transformers=[('num',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(strategy='median'))]),
#                                                    ['final_price',
#                                                     'initial_price', 'stock',
#                                                     'favorite',
#                                                     'seller_followers',
#                                                     'seller_products',
#                                                     'seller_rating',
#                                                     'seller_chats_responded_percentage',
#                                                     'seller_chat_time_reply',
#                                                     'variations_count',
#                                                     'image_count',
#                                                     'discount_percentage']),
#                                                   ('cat',
#                                                    Pipeline(steps=[('imputer',
#                                                                     SimpleImputer(fill_value='missing',
#                                                                                   strategy='constant')),
#                                                                    ('onehot',
#                                                                     OneHotEncoder(handle_unknown='ignore'))]),
#                                                    ['brand', 'country_of_origin',
#                                                     'warranty_duration',
#                                                     'warranty_type', 'material',
#                                                     'shipped_from', 'Diameter',
#                                                     'pan_type'])])),
#                  ('model',
#                   <catboost.core.CatBoostRegressor object at 0x0000027C23E74710>)]),
#  'ensemble_weights': array([0.37963228, 0.29837828, 0.32198944])}
