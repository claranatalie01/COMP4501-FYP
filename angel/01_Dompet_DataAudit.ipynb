# %% [markdown]
# ## EDA Dompet (Wallet) Category

# %%
# setup
! pip install --upgrade pip
! pip install numpy pandas
# Out:
# Requirement already satisfied: pip in /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages (26.0.1)
# Requirement already satisfied: numpy in /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages (1.26.4)
# Requirement already satisfied: pandas in /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages (2.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

PURPLE = '#7F77DD'
TEAL   = '#1D9E75'
AMBER  = '#EF9F27'
CORAL  = '#D85A30'
GRAY   = '#888780'

plt.rcParams['figure.dpi'] = 130
plt.rcParams['figure.figsize'] = (12, 5)
sns.set_theme(style='whitegrid', palette='muted')

# %%
df_dompet = pd.read_csv("../cleaned_dataset_revised_v3/dompet_final_cleaned.csv")
df_dompet.head()
# Out:
#             id                                              title  rating  \
# 0  20460325116  VONA Dompet Pria Lipat Pendek 2 Premium Kulit ...    4.79
# 1   4116469787  AIRA WALLET JIMS HONEY Dompet Panjang Mewah Wa...    4.82
# 2  13197858916  [Lms] Dompet Pria Impor Kulit PU Premium Resle...    4.88
# 3  11706914967  Baellerry RFID Anti Theft Card Dompet Kartu Wa...    4.83
# 4   3406406326  Wallts Aster - Dompet Wallet Kartu Pria dan Wa...    4.93
#
#    reviews  initial_price  final_price  stock  favorite  \
# 0      126       145000.0      53000.0  19259        71
# 1      174       108000.0      75000.0      0       160
# 2      169        89000.0      39800.0    107       150
# 3     1886        51000.0      42500.0    188        23
# 4     2872       259900.0     125000.0  10093        47
#
#                          seller_name  \
# 0                 VONA Official Shop
# 1                JIMS HONEY Deore.id
# 2                      LittlemaxShop
# 3                          MEGA JAYA
# 4  Wallts Wallet Goods Official Shop
#
#                                           breadcrumb  ...  leather_texture  \
# 0  ["Shopee","Men Bags","Wallets","Bifold & Trifo...  ...           Smooth
# 1   ["Shopee","Women Bags","Wallets","Long Wallets"]  ...            Other
# 2  ["Shopee","Men Bags","Wallets","Bifold & Trifo...  ...         Embossed
# 3   ["Shopee","Women Bags","Wallets","Card Holders"]  ...           Smooth
# 4  ["Shopee","Men Bags","Wallets","Bifold & Trifo...  ...            Other
#
#    leather_finish       leather_type  shipped_from_region  variations_count  \
# 0          Glossy  Synthetic Leather          Jabodetabek                 4
# 1           Other      Uncategorized              Unknown                12
# 2           Matte  Synthetic Leather          Jabodetabek                 4
# 3           Matte              Other          Jabodetabek                 5
# 4           Other      Uncategorized                 Java                 8
#
#    voucher_status  image_count video_count  discount     wallet_type
# 0               0           10           1   92000.0  Bifold/Trifold
# 1               0            8           1   33000.0     Long Wallet
# 2               0            8           0   49200.0  Bifold/Trifold
# 3               0            8           1    8500.0     Card Holder
# 4               0           10           1  134900.0  Bifold/Trifold
#
# [5 rows x 37 columns]

# %%
df_dompet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8238 entries, 0 to 8237
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 8238 non-null   int64
#  1   title                              8238 non-null   object
#  2   rating                             8238 non-null   float64
#  3   reviews                            8238 non-null   int64
#  4   initial_price                      8238 non-null   float64
#  5   final_price                        8238 non-null   float64
#  6   stock                              8238 non-null   int64
#  7   favorite                           8238 non-null   int64
#  8   seller_name                        8238 non-null   object
#  9   breadcrumb                         8238 non-null   object
#  10  seller_rating                      8238 non-null   float64
#  11  seller_products                    8238 non-null   int64
#  12  seller_chats_responded_percentage  8238 non-null   int64
#  13  seller_chat_time_reply             8238 non-null   float64
#  14  seller_joined_date                 8238 non-null   float64
#  15  seller_followers                   8238 non-null   int64
#  16  sold                               8238 non-null   int64
#  17  brand                              8238 non-null   object
#  18  gmv_cal                            8238 non-null   float64
#  19  motif                              8238 non-null   object
#  20  warranty_type                      8238 non-null   object
#  21  material                           8238 non-null   object
#  22  warranty_duration                  8238 non-null   object
#  23  country_of_origin                  8238 non-null   object
#  24  closure_type                       8238 non-null   object
#  25  card_slots                         8238 non-null   object
#  26  coin_slot                          8238 non-null   object
#  27  leather_texture                    8238 non-null   object
#  28  leather_finish                     8238 non-null   object
#  29  leather_type                       8238 non-null   object
#  30  shipped_from_region                8238 non-null   object
#  31  variations_count                   8238 non-null   int64
#  32  voucher_status                     8238 non-null   int64
#  33  image_count                        8238 non-null   int64
#  34  video_count                        8238 non-null   int64
#  35  discount                           8238 non-null   float64
#  36  wallet_type                        8238 non-null   object
# dtypes: float64(8), int64(12), object(17)
# memory usage: 2.3+ MB

# %%
df_dompet.describe()
# Out:
#                  id       rating       reviews  initial_price    final_price  \
# count  8.238000e+03  8238.000000   8238.000000   8.238000e+03    8238.000000
# mean   1.451229e+10     4.851902    455.956543   1.415731e+05   83260.027544
# std    7.209574e+09     0.239936   2117.333924   1.017651e+05   61805.774236
# min    2.438520e+07     0.000000      0.000000   5.000000e+03    3999.000000
# 25%    8.104729e+09     4.810000      5.000000   8.492500e+04   51900.000000
# 50%    1.639481e+10     4.890000     30.000000   1.300000e+05   70000.000000
# 75%    2.092056e+10     5.000000    161.000000   1.750000e+05   89900.000000
# max    2.945656e+10     5.000000  49830.000000   1.390000e+06  989000.000000
#
#               stock      favorite  seller_rating  seller_products  \
# count  8.238000e+03   8238.000000    8238.000000      8238.000000
# mean   2.253437e+03    120.650036       4.836622       346.186939
# std    3.097417e+04    303.955417       0.093812       257.750509
# min    0.000000e+00      0.000000       1.350000         5.000000
# 25%    1.100000e+01      6.000000       4.800000       149.000000
# 50%    9.200000e+01     26.000000       4.850000       285.000000
# 75%    7.250000e+02    112.000000       4.890000       517.000000
# max    1.727036e+06  14715.000000       5.000000      4356.000000
#
#        seller_chats_responded_percentage  seller_chat_time_reply  \
# count                        8238.000000             8238.000000
# mean                           90.197499                0.966824
# std                            13.311500                0.195107
# min                             3.000000                0.010000
# 25%                            87.000000                1.000000
# 50%                            95.000000                1.000000
# 75%                            99.000000                1.000000
# max                           100.000000                4.200000
#
#        seller_joined_date  seller_followers         sold       gmv_cal  \
# count         8238.000000      8.238000e+03  8238.000000  8.238000e+03
# mean             5.274744      1.399116e+05   491.994173  3.463592e+07
# std              2.064050      2.066273e+05  1215.477773  1.030620e+08
# min              0.104038      0.000000e+00     0.000000  0.000000e+00
# 25%              4.000000      4.000000e+03    10.000000  6.512500e+05
# 50%              6.000000      2.860000e+04    57.000000  4.077500e+06
# 75%              7.000000      2.332000e+05   318.000000  2.239226e+07
# max             10.464066      1.649637e+06  9800.000000  1.757700e+09
#
#        variations_count  voucher_status  image_count  video_count  \
# count       8238.000000     8238.000000  8238.000000  8238.000000
# mean           5.205632        0.003399     8.593712     0.575261
# std            4.828611        0.058204     2.039823     0.494333
# min            0.000000        0.000000     1.000000     0.000000
# 25%            2.000000        0.000000     8.000000     0.000000
# 50%            5.000000        0.000000     8.000000     1.000000
# 75%            8.000000        0.000000    10.000000     1.000000
# max           50.000000        1.000000    44.000000     1.000000
#
#             discount
# count    8238.000000
# mean    58313.037383
# std     58310.174160
# min         0.000000
# 25%     20000.000000
# 50%     50000.000000
# 75%     79000.000000
# max    920000.000000

# %% [markdown]
# ## Phase 1 - Data Audit

# %%
# df_dompet is already loaded — sanity check
print(f"Shape: {df_dompet.shape[0]:,} rows × {df_dompet.shape[1]} columns")

# ── dtype + null summary ──────────────────────────────────────────
schema = pd.DataFrame({
    'dtype'   : df_dompet.dtypes,
    'null_count': df_dompet.isnull().sum(),
    'null_pct' : (df_dompet.isnull().sum() / len(df_dompet) * 100).round(2),
    'nunique'  : df_dompet.nunique(),
    'sample'   : df_dompet.iloc[0],
})
schema = schema.sort_values('null_pct', ascending=False)

# Flag columns with >5% nulls
schema['flag'] = schema['null_pct'].apply(lambda x: '⚠ HIGH NULL' if x > 5 else ('· low null' if x > 0 else ''))

display(schema.style
    .background_gradient(subset=['null_pct'], cmap='Oranges')
    .set_caption('Schema & Null Audit — df_dompet')
    .format({'null_pct': '{:.2f}%'})
)
# Out:
# Shape: 8,238 rows × 37 columns
# <style type="text/css">
# #T_71cd4_row0_col2, #T_71cd4_row1_col2, #T_71cd4_row2_col2, #T_71cd4_row3_col2, #T_71cd4_row4_col2, #T_71cd4_row5_col2, #T_71cd4_row6_col2, #T_71cd4_row7_col2, #T_71cd4_row8_col2, #T_71cd4_row9_col2, #T_71cd4_row10_col2, #T_71cd4_row11_col2, #T_71cd4_row12_col2, #T_71cd4_row13_col2, #T_71cd4_row14_col2, #T_71cd4_row15_col2, #T_71cd4_row16_col2, #T_71cd4_row17_col2, #T_71cd4_row18_col2, #T_71cd4_row19_col2, #T_71cd4_row20_col2, #T_71cd4_row21_col2, #T_71cd4_row22_col2, #T_71cd4_row23_col2, #T_71cd4_row24_col2, #T_71cd4_row25_col2, #T_71cd4_row26_col2, #T_71cd4_row27_col2, #T_71cd4_row28_col2, #T_71cd4_row29_col2, #T_71cd4_row30_col2, #T_71cd4_row31_col2, #T_71cd4_row32_col2, #T_71cd4_row33_col2, #T_71cd4_row34_col2, #T_71cd4_row35_col2, #T_71cd4_row36_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_71cd4">
#   <caption>Schema & Null Audit — df_dompet</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71cd4_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_71cd4_level0_col1" class="col_heading level0 col1" >null_count</th>
#       <th id="T_71cd4_level0_col2" class="col_heading level0 col2" >null_pct</th>
#       <th id="T_71cd4_level0_col3" class="col_heading level0 col3" >nunique</th>
#       <th id="T_71cd4_level0_col4" class="col_heading level0 col4" >sample</th>
#       <th id="T_71cd4_level0_col5" class="col_heading level0 col5" >flag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71cd4_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_71cd4_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_71cd4_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_71cd4_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_71cd4_row0_col3" class="data row0 col3" >4190</td>
#       <td id="T_71cd4_row0_col4" class="data row0 col4" >20460325116</td>
#       <td id="T_71cd4_row0_col5" class="data row0 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row1" class="row_heading level0 row1" >motif</th>
#       <td id="T_71cd4_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_71cd4_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_71cd4_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_71cd4_row1_col3" class="data row1 col3" >7</td>
#       <td id="T_71cd4_row1_col4" class="data row1 col4" >Solid</td>
#       <td id="T_71cd4_row1_col5" class="data row1 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row2" class="row_heading level0 row2" >material</th>
#       <td id="T_71cd4_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_71cd4_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_71cd4_row2_col2" class="data row2 col2" >0.00%</td>
#       <td id="T_71cd4_row2_col3" class="data row2 col3" >6</td>
#       <td id="T_71cd4_row2_col4" class="data row2 col4" >Synthetic Leather</td>
#       <td id="T_71cd4_row2_col5" class="data row2 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row3" class="row_heading level0 row3" >warranty_duration</th>
#       <td id="T_71cd4_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_71cd4_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_71cd4_row3_col2" class="data row3 col2" >0.00%</td>
#       <td id="T_71cd4_row3_col3" class="data row3 col3" >5</td>
#       <td id="T_71cd4_row3_col4" class="data row3 col4" >No Warranty</td>
#       <td id="T_71cd4_row3_col5" class="data row3 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row4" class="row_heading level0 row4" >country_of_origin</th>
#       <td id="T_71cd4_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_71cd4_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_71cd4_row4_col2" class="data row4 col2" >0.00%</td>
#       <td id="T_71cd4_row4_col3" class="data row4 col3" >13</td>
#       <td id="T_71cd4_row4_col4" class="data row4 col4" >Indonesia</td>
#       <td id="T_71cd4_row4_col5" class="data row4 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row5" class="row_heading level0 row5" >closure_type</th>
#       <td id="T_71cd4_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_71cd4_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_71cd4_row5_col2" class="data row5 col2" >0.00%</td>
#       <td id="T_71cd4_row5_col3" class="data row5 col3" >7</td>
#       <td id="T_71cd4_row5_col4" class="data row5 col4" >Other</td>
#       <td id="T_71cd4_row5_col5" class="data row5 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row6" class="row_heading level0 row6" >card_slots</th>
#       <td id="T_71cd4_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_71cd4_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_71cd4_row6_col2" class="data row6 col2" >0.00%</td>
#       <td id="T_71cd4_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_71cd4_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_71cd4_row6_col5" class="data row6 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row7" class="row_heading level0 row7" >coin_slot</th>
#       <td id="T_71cd4_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_71cd4_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_71cd4_row7_col2" class="data row7 col2" >0.00%</td>
#       <td id="T_71cd4_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_71cd4_row7_col4" class="data row7 col4" >Tidak</td>
#       <td id="T_71cd4_row7_col5" class="data row7 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row8" class="row_heading level0 row8" >leather_texture</th>
#       <td id="T_71cd4_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_71cd4_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_71cd4_row8_col2" class="data row8 col2" >0.00%</td>
#       <td id="T_71cd4_row8_col3" class="data row8 col3" >8</td>
#       <td id="T_71cd4_row8_col4" class="data row8 col4" >Smooth</td>
#       <td id="T_71cd4_row8_col5" class="data row8 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row9" class="row_heading level0 row9" >leather_finish</th>
#       <td id="T_71cd4_row9_col0" class="data row9 col0" >object</td>
#       <td id="T_71cd4_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_71cd4_row9_col2" class="data row9 col2" >0.00%</td>
#       <td id="T_71cd4_row9_col3" class="data row9 col3" >4</td>
#       <td id="T_71cd4_row9_col4" class="data row9 col4" >Glossy</td>
#       <td id="T_71cd4_row9_col5" class="data row9 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row10" class="row_heading level0 row10" >leather_type</th>
#       <td id="T_71cd4_row10_col0" class="data row10 col0" >object</td>
#       <td id="T_71cd4_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_71cd4_row10_col2" class="data row10 col2" >0.00%</td>
#       <td id="T_71cd4_row10_col3" class="data row10 col3" >5</td>
#       <td id="T_71cd4_row10_col4" class="data row10 col4" >Synthetic Leather</td>
#       <td id="T_71cd4_row10_col5" class="data row10 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row11" class="row_heading level0 row11" >shipped_from_region</th>
#       <td id="T_71cd4_row11_col0" class="data row11 col0" >object</td>
#       <td id="T_71cd4_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_71cd4_row11_col2" class="data row11 col2" >0.00%</td>
#       <td id="T_71cd4_row11_col3" class="data row11 col3" >8</td>
#       <td id="T_71cd4_row11_col4" class="data row11 col4" >Jabodetabek</td>
#       <td id="T_71cd4_row11_col5" class="data row11 col5" ></td>
#     </tr>
#     <tr>
#       <th id="T_71cd4_level0_row12" class="row_heading level0 row12" >variations_count</th>
#       <td id="T_71cd4_row12_col0" class="data row12 col0" >int64</td>
#       <td id="T_71cd4_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_71cd4_row12_col2" class="data row12 col2" >0.00%</td>
#       <td id="T_71cd4_row12_col3" class="data row12 col3" >41</td>
#       <td id="T_71cd4_row12_col4" class="

# %%
# ── Duplicates ────────────────────────────────────────────────────
n_dup_rows  = df_dompet.duplicated().sum()
n_dup_ids   = df_dompet['id'].duplicated().sum()
n_dup_title = df_dompet['title'].duplicated().sum()

print(f"Fully duplicate rows : {n_dup_rows}")
print(f"Duplicate product IDs: {n_dup_ids}")
print(f"Duplicate titles     : {n_dup_title}  (may be variant listings)")

# Show any duplicate IDs if they exist
if n_dup_ids > 0:
    dup_sample = df_dompet[df_dompet.duplicated(subset='id', keep=False)]
    display(dup_sample[['id', 'title', 'seller_name', 'final_price']].head(10))
# Out:
# Fully duplicate rows : 4026
# Duplicate product IDs: 4048
# Duplicate titles     : 4108  (may be variant listings)
#             id                                              title  \
# 0  20460325116  VONA Dompet Pria Lipat Pendek 2 Premium Kulit ...
# 1   4116469787  AIRA WALLET JIMS HONEY Dompet Panjang Mewah Wa...
# 2  13197858916  [Lms] Dompet Pria Impor Kulit PU Premium Resle...
# 3  11706914967  Baellerry RFID Anti Theft Card Dompet Kartu Wa...
# 4   3406406326  Wallts Aster - Dompet Wallet Kartu Pria dan Wa...
# 5  14600249323  Tas Selempang Pria dan Wanita Slingbag Casual ...
# 6   5145325874          Dompet Lipat Baellerry Original New D3001
# 7  14265636977  BAELLERRY N8625 Dompet Kartu Wanita Bahan Kuli...
# 8   1133139296  DW03 Dompet Wanita Baellerry Fashion Cewek Ker...
# 9  18538335566  BAELLERRY N2370 Dompet Wanita Kecil Lipat Baha...
#
#                          seller_name  final_price
# 0                 VONA Official Shop      53000.0
# 1                JIMS HONEY Deore.id      75000.0
# 2                      LittlemaxShop      39800.0
# 3                          MEGA JAYA      42500.0
# 4  Wallts Wallet Goods Official Shop     125000.0
# 5           willgoodme official shop      23000.0
# 6                          VION SHOP      45000.0
# 7  Baellerry Indonesia Official Shop      53643.0
# 8                     Sweet & Lovely      44444.0
# 9  Baellerry Indonesia Official Shop      64393.0

# %%
# ── Fix known type issues ─────────────────────────────────────────
df = df_dompet.copy()  # work on a copy from here on

# seller_joined_date: likely stored as float (epoch days or timestamp)
if df['seller_joined_date'].dtype != 'datetime64[ns]':
    try:
        df['seller_joined_date'] = pd.to_datetime(df['seller_joined_date'], unit='s')
        print("seller_joined_date → parsed as Unix timestamp (seconds)")
    except:
        df['seller_joined_date'] = pd.to_datetime(df['seller_joined_date'])
        print("seller_joined_date → parsed as datetime string")

# voucher_status: treat as categorical flag (0/1)
df['voucher_status'] = df['voucher_status'].astype('int8')

# video_count: should be int
df['video_count'] = df['video_count'].fillna(0).astype('int8')

# Categorical string cols — strip whitespace & normalise case
cat_cols = ['leather_texture', 'leather_finish', 'leather_type',
            'shipped_from_region', 'wallet_type']
for col in cat_cols:
    df[col] = df[col].str.strip().str.title()

binary_cols = ['coin_slot']
for col in binary_cols:
    df[col] = df[col].map({'Ya': 1, 'Tidak': 0}).astype('int8')

print("\nTypes after corrections:")
print(df[cat_cols + ['seller_joined_date', 'voucher_status', 'video_count', 'coin_slot']].dtypes)
# Out:
# seller_joined_date → parsed as Unix timestamp (seconds)
#
# Types after corrections:
# leather_texture                object
# leather_finish                 object
# leather_type                   object
# shipped_from_region            object
# wallet_type                    object
# seller_joined_date     datetime64[ns]
# voucher_status                   int8
# video_count                      int8
# coin_slot                        int8
# dtype: object

# %%
# ── Flag business-logic violations ────────────────────────────────
checks = {
    'rating == 0 (inactive/new)'        : (df['rating'] == 0).sum(),
    'reviews == 0'                      : (df['reviews'] == 0).sum(),
    'sold == 0'                         : (df['sold'] == 0).sum(),
    'stock == 0 (out-of-stock)'         : (df['stock'] == 0).sum(),
    'final_price > initial_price'       : (df['final_price'] > df['initial_price']).sum(),
    'discount == 0 but price changed'   : ((df['discount'] == 0) &
                                             (df['final_price'] != df['initial_price'])).sum(),
    'gmv_cal == 0'                      : (df['gmv_cal'] == 0).sum(),
    'image_count < 3 (below Shopee min)': (df['image_count'] < 3).sum(),
    'seller_rating < 4.0'               : (df['seller_rating'] < 4.0).sum(),
}

check_df = pd.DataFrame(checks.items(), columns=['Check', 'Count'])
check_df['Pct of dataset'] = (check_df['Count'] / len(df) * 100).round(2)
check_df['Action'] = check_df['Count'].apply(
    lambda x: '✓ None found' if x == 0 else '⚠ Review'
)
display(check_df.style.set_caption('Business Logic Violation Audit'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_92841">
#   <caption>Business Logic Violation Audit</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92841_level0_col0" class="col_heading level0 col0" >Check</th>
#       <th id="T_92841_level0_col1" class="col_heading level0 col1" >Count</th>
#       <th id="T_92841_level0_col2" class="col_heading level0 col2" >Pct of dataset</th>
#       <th id="T_92841_level0_col3" class="col_heading level0 col3" >Action</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92841_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92841_row0_col0" class="data row0 col0" >rating == 0 (inactive/new)</td>
#       <td id="T_92841_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_92841_row0_col2" class="data row0 col2" >0.040000</td>
#       <td id="T_92841_row0_col3" class="data row0 col3" >⚠ Review</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92841_row1_col0" class="data row1 col0" >reviews == 0</td>
#       <td id="T_92841_row1_col1" class="data row1 col1" >41</td>
#       <td id="T_92841_row1_col2" class="data row1 col2" >0.500000</td>
#       <td id="T_92841_row1_col3" class="data row1 col3" >⚠ Review</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92841_row2_col0" class="data row2 col0" >sold == 0</td>
#       <td id="T_92841_row2_col1" class="data row2 col1" >90</td>
#       <td id="T_92841_row2_col2" class="data row2 col2" >1.090000</td>
#       <td id="T_92841_row2_col3" class="data row2 col3" >⚠ Review</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92841_row3_col0" class="data row3 col0" >stock == 0 (out-of-stock)</td>
#       <td id="T_92841_row3_col1" class="data row3 col1" >1050</td>
#       <td id="T_92841_row3_col2" class="data row3 col2" >12.750000</td>
#       <td id="T_92841_row3_col3" class="data row3 col3" >⚠ Review</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92841_row4_col0" class="data row4 col0" >final_price > initial_price</td>
#       <td id="T_92841_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_92841_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_92841_row4_col3" class="data row4 col3" >✓ None found</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92841_row5_col0" class="data row5 col0" >discount == 0 but price changed</td>
#       <td id="T_92841_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_92841_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_92841_row5_col3" class="data row5 col3" >✓ None found</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92841_row6_col0" class="data row6 col0" >gmv_cal == 0</td>
#       <td id="T_92841_row6_col1" class="data row6 col1" >90</td>
#       <td id="T_92841_row6_col2" class="data row6 col2" >1.090000</td>
#       <td id="T_92841_row6_col3" class="data row6 col3" >⚠ Review</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_92841_row7_col0" class="data row7 col0" >image_count < 3 (below Shopee min)</td>
#       <td id="T_92841_row7_col1" class="data row7 col1" >7</td>
#       <td id="T_92841_row7_col2" class="data row7 col2" >0.080000</td>
#       <td id="T_92841_row7_col3" class="data row7 col3" >⚠ Review</td>
#     </tr>
#     <tr>
#       <th id="T_92841_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_92841_row8_col0" class="data row8 col0" >seller_rating < 4.0</td>
#       <td id="T_92841_row8_col1" class="data row8 col1" >2</td>
#       <td id="T_92841_row8_col2" class="data row8 col2" >0.020000</td>
#       <td id="T_92841_row8_col3" class="data row8 col3" >⚠ Review</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
df.to_csv("./data/dompet_final_cleaned_v1.csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8238 entries, 0 to 8237
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 8238 non-null   int64
#  1   title                              8238 non-null   object
#  2   rating                             8238 non-null   float64
#  3   reviews                            8238 non-null   int64
#  4   initial_price                      8238 non-null   float64
#  5   final_price                        8238 non-null   float64
#  6   stock                              8238 non-null   int64
#  7   favorite                           8238 non-null   int64
#  8   seller_name                        8238 non-null   object
#  9   breadcrumb                         8238 non-null   object
#  10  seller_rating                      8238 non-null   float64
#  11  seller_products                    8238 non-null   int64
#  12  seller_chats_responded_percentage  8238 non-null   int64
#  13  seller_chat_time_reply             8238 non-null   float64
#  14  seller_joined_date                 8238 non-null   datetime64[ns]
#  15  seller_followers                   8238 non-null   int64
#  16  sold                               8238 non-null   int64
#  17  brand                              8238 non-null   object
#  18  gmv_cal                            8238 non-null   float64
#  19  motif                              8238 non-null   object
#  20  warranty_type                      8238 non-null   object
#  21  material                           8238 non-null   object
#  22  warranty_duration                  8238 non-null   object
#  23  country_of_origin                  8238 non-null   object
#  24  closure_type                       8238 non-null   object
#  25  card_slots                         8238 non-null   object
#  26  coin_slot                          8238 non-null   int8
#  27  leather_texture                    8238 non-null   object
#  28  leather_finish                     8238 non-null   object
#  29  leather_type                       8238 non-null   object
#  30  shipped_from_region                8238 non-null   object
#  31  variations_count                   8238 non-null   int64
#  32  voucher_status                     8238 non-null   int8
#  33  image_count                        8238 non-null   int64
#  34  video_count                        8238 non-null   int8
#  35  discount                           8238 non-null   float64
#  36  wallet_type                        8238 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(10), int8(3), object(16)
# memory usage: 2.2+ MB

# %%
df['voucher_status'].value_counts(dropna=False)
# Out:
# voucher_status
# 0    8210
# 1      28
# Name: count, dtype: int64

# %%
# ── IQR-based outlier scan on key numeric cols ────────────────────
numeric_cols = ['final_price', 'initial_price', 'reviews', 'sold',
                'stock', 'favorite', 'gmv_cal', 'seller_followers', 'rating']

outlier_report = []
for col in numeric_cols:
    Q1  = df[col].quantile(0.25)
    Q3  = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lo, hi = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR
    n_out = ((df[col] < lo) | (df[col] > hi)).sum()
    outlier_report.append({
        'column'      : col,
        'Q1'          : round(Q1, 1),
        'Q3'          : round(Q3, 1),
        'IQR_lower'   : round(lo, 1),
        'IQR_upper'   : round(hi, 1),
        'max_value'   : round(df[col].max(), 1),
        'n_outliers'  : n_out,
        'outlier_pct' : round(n_out / len(df) * 100, 2),
    })

out_df = pd.DataFrame(outlier_report)
display(out_df.style
    .background_gradient(subset=['outlier_pct'], cmap='Reds')
    .set_caption('IQR Outlier Scan — Key Numeric Columns')
    .format({'outlier_pct': '{:.2f}%'})
)

# Note: do NOT remove outliers yet — top sellers ARE outliers by design.
# Log-transformation (Phase 6) handles this more appropriately.
# Out:
# <style type="text/css">
# #T_0974b_row0_col7 {
#   background-color: #f6563d;
#   color: #f1f1f1;
# }
# #T_0974b_row1_col7 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_0974b_row2_col7 {
#   background-color: #bc141a;
#   color: #f1f1f1;
# }
# #T_0974b_row3_col7 {
#   background-color: #cc191e;
#   color: #f1f1f1;
# }
# #T_0974b_row4_col7 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_0974b_row5_col7 {
#   background-color: #d92523;
#   color: #f1f1f1;
# }
# #T_0974b_row6_col7 {
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_0974b_row7_col7 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_0974b_row8_col7 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_0974b">
#   <caption>IQR Outlier Scan — Key Numeric Columns</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0974b_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_0974b_level0_col1" class="col_heading level0 col1" >Q1</th>
#       <th id="T_0974b_level0_col2" class="col_heading level0 col2" >Q3</th>
#       <th id="T_0974b_level0_col3" class="col_heading level0 col3" >IQR_lower</th>
#       <th id="T_0974b_level0_col4" class="col_heading level0 col4" >IQR_upper</th>
#       <th id="T_0974b_level0_col5" class="col_heading level0 col5" >max_value</th>
#       <th id="T_0974b_level0_col6" class="col_heading level0 col6" >n_outliers</th>
#       <th id="T_0974b_level0_col7" class="col_heading level0 col7" >outlier_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0974b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0974b_row0_col0" class="data row0 col0" >final_price</td>
#       <td id="T_0974b_row0_col1" class="data row0 col1" >51900.000000</td>
#       <td id="T_0974b_row0_col2" class="data row0 col2" >89900.000000</td>
#       <td id="T_0974b_row0_col3" class="data row0 col3" >-5100.000000</td>
#       <td id="T_0974b_row0_col4" class="data row0 col4" >146900.000000</td>
#       <td id="T_0974b_row0_col5" class="data row0 col5" >989000.000000</td>
#       <td id="T_0974b_row0_col6" class="data row0 col6" >987</td>
#       <td id="T_0974b_row0_col7" class="data row0 col7" >11.98%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0974b_row1_col0" class="data row1 col0" >initial_price</td>
#       <td id="T_0974b_row1_col1" class="data row1 col1" >84925.000000</td>
#       <td id="T_0974b_row1_col2" class="data row1 col2" >175000.000000</td>
#       <td id="T_0974b_row1_col3" class="data row1 col3" >-50187.500000</td>
#       <td id="T_0974b_row1_col4" class="data row1 col4" >310112.500000</td>
#       <td id="T_0974b_row1_col5" class="data row1 col5" >1390000.000000</td>
#       <td id="T_0974b_row1_col6" class="data row1 col6" >369</td>
#       <td id="T_0974b_row1_col7" class="data row1 col7" >4.48%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0974b_row2_col0" class="data row2 col0" >reviews</td>
#       <td id="T_0974b_row2_col1" class="data row2 col1" >5.000000</td>
#       <td id="T_0974b_row2_col2" class="data row2 col2" >161.000000</td>
#       <td id="T_0974b_row2_col3" class="data row2 col3" >-229.000000</td>
#       <td id="T_0974b_row2_col4" class="data row2 col4" >395.000000</td>
#       <td id="T_0974b_row2_col5" class="data row2 col5" >49830.000000</td>
#       <td id="T_0974b_row2_col6" class="data row2 col6" >1278</td>
#       <td id="T_0974b_row2_col7" class="data row2 col7" >15.51%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0974b_row3_col0" class="data row3 col0" >sold</td>
#       <td id="T_0974b_row3_col1" class="data row3 col1" >10.000000</td>
#       <td id="T_0974b_row3_col2" class="data row3 col2" >318.000000</td>
#       <td id="T_0974b_row3_col3" class="data row3 col3" >-452.000000</td>
#       <td id="T_0974b_row3_col4" class="data row3 col4" >780.000000</td>
#       <td id="T_0974b_row3_col5" class="data row3 col5" >9800.000000</td>
#       <td id="T_0974b_row3_col6" class="data row3 col6" >1212</td>
#       <td id="T_0974b_row3_col7" class="data row3 col7" >14.71%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0974b_row4_col0" class="data row4 col0" >stock</td>
#       <td id="T_0974b_row4_col1" class="data row4 col1" >11.000000</td>
#       <td id="T_0974b_row4_col2" class="data row4 col2" >725.000000</td>
#       <td id="T_0974b_row4_col3" class="data row4 col3" >-1060.000000</td>
#       <td id="T_0974b_row4_col4" class="data row4 col4" >1796.000000</td>
#       <td id="T_0974b_row4_col5" class="data row4 col5" >1727036.000000</td>
#       <td id="T_0974b_row4_col6" class="data row4 col6" >1514</td>
#       <td id="T_0974b_row4_col7" class="data row4 col7" >18.38%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0974b_row5_col0" class="data row5 col0" >favorite</td>
#       <td id="T_0974b_row5_col1" class="data row5 col1" >6.000000</td>
#       <td id="T_0974b_row5_col2" class="data row5 col2" >112.000000</td>
#       <td id="T_0974b_row5_col3" class="data row5 col3" >-153.000000</td>
#       <td id="T_0974b_row5_col4" class="data row5 col4" >271.000000</td>
#       <td id="T_0974b_row5_col5" class="data row5 col5" >14715.000000</td>
#       <td id="T_0974b_row5_col6" class="data row5 col6" >1159</td>
#       <td id="T_0974b_row5_col7" class="data row5 col7" >14.07%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0974b_row6_col0" class="data row6 col0" >gmv_cal</td>
#       <td id="T_0974b_row6_col1" class="data row6 col1" >651250.000000</td>
#       <td id="T_0974b_row6_col2" class="data row6 col2" >22392263.200000</td>
#       <td id="T_0974b_row6_col3" class="data row6 col3" >-31960269.900000</td>
#       <td id="T_0974b_row6_col4" class="data row6 col4" >55003783.100000</td>
#       <td id="T_0974b_row6_col5" class="data row6 col5" >1757700000.000000</td>
#       <td id="T_0974b_row6_col6" class="data row6 col6" >1149</td>
#       <td id="T_0974b_row6_col7" class="data row6 col7" >13.95%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0974b_row7_col0" class="data row7 col0" >seller_followers</td>
#       <td id="T_0974b_row7_col1" class="data row7 col1" >4000.000000</td>
#       <td id="T_0974b_row7_col2" class="data row7 col2" >233200.000000</td>
#       <td id="T_0974b_row7_col3" class="data row7 col3" >-339800.000000</td>
#       <td id="T_0974b_row7_col4" class="data row7 col4" >577000.000000</td>
#       <td id="T_0974b_row7_col5" class="data row7 col5" >1649637.000000</td>
#       <td id="T_0974b_row7_col6" class="data row7 col6" >661</td>
#       <td id="T_0974b_row7_col7" class="data row7 col7" >8.02%</td>
#     </tr>
#     <tr>
#       <th id="T_0974b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0974b_row8_col0" class="data row8 col0" >rating</td>
#       <td id="T_0974b_row8_col1" class="data row8 col1" >4.800000</td>
#       <td id="T_0974b_row8_col2" class="data row8 col2" >5.000000</td>
#       <td id="T_0974b_row8_col3" class="data row8 col3" >4.500000</td>
#       <td id="T_0974b_row8_col4" class="data row8 col4" >5.300000</td>
#       <td id="T_0974b_row8_col5" class="data row8 col5" >5.000000</td>
#       <td id="T_0974b_row8_col6" class="data row8 col6" >331</td>
#       <td id="T_0974b_row8_col7" class="data row8 col7" >4.02%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ── Null heatmap + rating/price distribution ──────────────────────
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# (a) Null heatmap — columns with any nulls only
null_cols = df.columns[df.isnull().any()].tolist()
if null_cols:
    sns.heatmap(df[null_cols].isnull(),
                yticklabels=False, cbar=False,
                cmap='OrRd', ax=axes[0])
    axes[0].set_title('Null pattern (cols with missing data)', fontsize=11)
    axes[0].tick_params(axis='x', rotation=45)
else:
    axes[0].text(0.5, 0.5, 'No nulls found ✓', ha='center', va='center', fontsize=13)
    axes[0].set_title('Null pattern', fontsize=11)

# (b) Rating distribution — compressed, show left tail
axes[1].hist(df['rating'], bins=40, color='#7F77DD', edgecolor='white', linewidth=0.4)
axes[1].axvline(df['rating'].median(), color='#D85A30', linestyle='--', lw=1.5,
               label=f"Median: {df['rating'].median()}")
axes[1].axvline(4.5, color='#1D9E75', linestyle=':', lw=1.5, label='Threshold: 4.5')
axes[1].set_title('Rating distribution', fontsize=11)
axes[1].set_xlabel('Rating')
axes[1].legend(fontsize=9)

# (c) final_price (log scale to handle extreme right skew)
axes[2].hist(np.log1p(df['final_price']), bins=50,
             color='#1D9E75', edgecolor='white', linewidth=0.4)
axes[2].set_title('log(final_price) distribution', fontsize=11)
axes[2].set_xlabel('log1p(IDR)')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/g_/fmz6fbfx0l96hfjsv2764ypw0000gn/T/ipykernel_97475/3382700096.py:31: UserWarning: Glyph 10003 (\N{CHECK MARK}) missing from current font.
#   plt.tight_layout()
# /Users/angelinemarcellelukito/miniconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 10003 (\N{CHECK MARK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# ── Value counts for all categorical columns ──────────────────────
cat_audit_cols = [
    'wallet_type', 'leather_type', 'leather_texture',
    'leather_finish', 'shipped_from_region', 'voucher_status'
]

fig, axes = plt.subplots(2, 3, figsize=(18, 9))
axes = axes.flatten()

for i, col in enumerate(cat_audit_cols):
    vc = df[col].value_counts()
    axes[i].barh(vc.index, vc.values, color='#AFA9EC')
    axes[i].set_title(f'{col}  (n={vc.sum():,})', fontsize=10)
    axes[i].invert_yaxis()
    # Annotate pct
    for j, (val, cnt) in enumerate(zip(vc.index, vc.values)):
        axes[i].text(cnt + vc.max() * 0.01, j,
                     f'{cnt/len(df)*100:.1f}%', va='center', fontsize=8)

plt.suptitle('Categorical column value distributions', fontsize=12, y=1.01)
plt.tight_layout()
plt.show()

# Print "Other" / "Uncategorized" rates explicitly
print("\n── Dirty category rates ──")
for col in ['leather_type', 'leather_texture', 'leather_finish']:
    dirty = df[col].isin(['Other', 'Uncategorized', 'Unknown']).sum()
    print(f"  {col}: {dirty} rows ({dirty/len(df)*100:.1f}%) are Other/Uncategorized/Unknown")
# Out:
# ── Dirty category rates ──
#   leather_type: 7094 rows (86.1%) are Other/Uncategorized/Unknown
#   leather_texture: 5320 rows (64.6%) are Other/Uncategorized/Unknown
#   leather_finish: 5493 rows (66.7%) are Other/Uncategorized/Unknown

# %%
# ── Print a structured audit summary ──────────────────────────────
print("=" * 58)
print("  PHASE 1 AUDIT SUMMARY — df_dompet")
print("=" * 58)
print(f"  Rows            : {len(df):,}")
print(f"  Columns         : {df.shape[1]}")
print(f"  Full duplicates : {df.duplicated().sum()}")
print(f"  Cols w/ nulls   : {df.isnull().any().sum()}")
print(f"  Zero-rating rows: {(df['rating']==0).sum()} — exclude from roadmap modeling")
print(f"  Zero-review rows: {(df['reviews']==0).sum()} — likely new/inactive listings")
print(f"  Zero-sold rows  : {(df['sold']==0).sum()} — tag as 'no traction' segment")
print(f"  Max reviews     : {df['reviews'].max():,} — extreme right skew → log-transform")
print(f"  Max GMV         : IDR {df['gmv_cal'].max():,.0f} → log-transform")
print(f"  Rating median   : {df['rating'].median()} (mean {df['rating'].mean():.3f})")
print("─" * 58)
print("  DECISIONS FOR PHASE 2:")
print("  · Log-transform: reviews, sold, gmv_cal, stock,")
print("                   favorites, seller_followers, final_price")
print("  · Impute/flag  : leather_type 'Uncategorized' → 'Unknown'")
print("  · Keep outliers: top sellers are signal, not noise")
print("  · Target var   : gmv_cal (or sold) — pick one, avoid leakage")
print("=" * 58)
# Out:
# ==========================================================
#   PHASE 1 AUDIT SUMMARY — df_dompet
# ==========================================================
#   Rows            : 8,238
#   Columns         : 37
#   Full duplicates : 4026
#   Cols w/ nulls   : 0
#   Zero-rating rows: 3 — exclude from roadmap modeling
#   Zero-review rows: 41 — likely new/inactive listings
#   Zero-sold rows  : 90 — tag as 'no traction' segment
#   Max reviews     : 49,830 — extreme right skew → log-transform
#   Max GMV         : IDR 1,757,700,000 → log-transform
#   Rating median   : 4.89 (mean 4.852)
# ──────────────────────────────────────────────────────────
#   DECISIONS FOR PHASE 2:
#   · Log-transform: reviews, sold, gmv_cal, stock,
#                    favorites, seller_followers, final_price
#   · Impute/flag  : leather_type 'Uncategorized' → 'Unknown'
#   · Keep outliers: top sellers are signal, not noise
#   · Target var   : gmv_cal (or sold) — pick one, avoid leakage
# ==========================================================

# %% [markdown]
# ### Further Clean Data Based on Audit

# %%
audit_df = df.copy()

# Step 1: drop fake listings (0 sold, but has reviews — likely relisted)
audit_df = audit_df[~((audit_df['sold'] == 0) & (audit_df['reviews'] > 0))]

# Step 2: deduplicate by ID, keep highest sold
audit_df = (audit_df
            .sort_values('sold', ascending=False)
            .drop_duplicates(subset='id', keep='first')
            .copy())

# Step 3: drop price outliers
audit_df = audit_df[audit_df['final_price'] <= 975_000].copy()

# Step 4: manipulate listings that have sold == 0 to be 

print(f"Final clean dataset: {len(audit_df):,} rows")
# Out:
# Final clean dataset: 4,154 rows

# %%
mask = (audit_df['reviews'] > audit_df['sold']) & (audit_df['reviews'] > 50)

audit_df.loc[mask, 'sold'] = (audit_df.loc[mask, 'reviews'] * 1.1).round().astype(int)

print(f"Listings reassigned: {mask.sum():,}")
print(f"\nSample check:")
print(audit_df.loc[mask, ['id', 'title', 'sold', 'reviews']].head(10))
# Out:
# Listings reassigned: 95
#
# Sample check:
#                id                                              title   sold  \
# 4284    473283993  HS [COD]  Baellerry Dompet Pria Eksklusif Mode...   5905
# 7958  20101904986  Hathin muii  Genie Wallet Dompet Wanita Origin...  17625
# 1087    464064247  HS [COD] Dompet Baellerry Panjang 22 Slot Term...   5106
# 4939   1321242282          JFR Dompet Panjang Pria Bahan Kanvas JP09  22114
# 4277   1867359886  JFR Dompet Pria Bahan Kulit Asli Motif Full Gr...  20337
# 3594   7785775528  TASBLUE Dompet Pria Lipat Dompet Kulit Men Fas...   4521
# 3151  12724646094  BAELLERRY NR073 Dompet Kartu Wanita Bahan Kuli...   5508
# 6711   9620603233  Dompet BAELLERRY Original Wanita Panjang Multi...   3873
# 4404   1864613772  BAELLERRY D3001 Dompet Pria Bahan Kulit PU Lea...  10491
# 1048  13944502139  BAELLERRY N5013 Dompet Wanita Kecil Bahan Kuli...  34058
#
#       reviews
# 4284     5368
# 7958    16023
# 1087     4642
# 4939    20104
# 4277    18488
# 3594     4110
# 3151     5007
# 6711     3521
# 4404     9537
# 1048    30962

# %%
# Recalculate GMV for reassigned rows using final_price * new sold
audit_df.loc[mask, 'gmv_cal'] = audit_df.loc[mask, 'final_price'] * audit_df.loc[mask, 'sold']

print(f"\nGMV recalculated for {mask.sum():,} relisted listings")
print(audit_df.loc[mask, ['id', 'sold', 'reviews', 'final_price', 'gmv_cal']].head(5))
# Out:
# GMV recalculated for 95 relisted listings
#                id   sold  reviews  final_price       gmv_cal
# 4284    473283993   5905     5368      44200.0  2.610010e+08
# 7958  20101904986  17625    16023      55900.0  9.852375e+08
# 1087    464064247   5106     4642      64000.0  3.267840e+08
# 4939   1321242282  22114    20104      57750.0  1.277084e+09
# 4277   1867359886  20337    18488     130000.0  2.643810e+09

# %%
lebihbanyakreviews = audit_df[audit_df['sold'] < audit_df['reviews']]
lebihbanyakreviews[['id', 'title', 'sold', 'reviews']].head(20)
# Out:
# Empty DataFrame
# Columns: [id, title, sold, reviews]
# Index: []

# %%
stocknol = audit_df[audit_df['sold'] == 0]
stocknol[['id', 'title', 'sold', 'reviews', 'coin_slot']].head(20)
# Out:
#                id                                              title  sold  \
# 2032    677830772  LA-1042E - Louis Andreano - Dompet Pria Kulit ...     0
# 7051  22453229791       JIMS HONEY DOMPET PANJANG WANITA LALA WALLET     0
# 4990  19269515801  SMIGGLE BLAST/ LETS PLAY JUNIOR LANYARD WALLET...     0
# 2602  22419467459  DOMPET LIPAT WANITA KOREA SLOT KARTU UANG RESL...     0
# 6817  28866362250  Harry Potter x Miniso | Dompet | Pet Scarf | T...     0
# 429   22334181441          Dompet Kartu | Card Holder | Free sticker     0
# 7668   7742704458  BRGUNIK Dompet Pria Baellerry Panjang Baellerr...     0
# 3006  10965863795              MAYA - Dompet Pocket Tempat Hp Wanita     0
# 4251   3958684930  PREMIUM FLIP CASEME FOR SAMSUNG NOTE 20 ULTRA ...     0
# 3072  23824795698  Jims Honey Vallerie Wallet Dompet Panjang Wani...     0
# 6675   9016037211  SELUSA LEXA WALLET (Free Hardbox Exclusive) | ...     0
# 5403  17124446834                        MAYA | Dompet pocket Wanita     0
# 3502   4251967090                          DOMPET PEDRO* MINI WALLET     0
# 7189  21534169170  DOMPET BAELLERRY ORIGINAL KULIT PANJANG PREMIU...     0
# 4888  22936145500  Alvira Pouch By Ratu Bilqis Dompet Wanita Keki...     0
# 6753  24521289624    Jims Honey - Little Agnes - Dompet Lipat Wanita     0
# 291    5916216891  JIMS HONEY AIRA WALLET DOMPET WANITA PANJANG T...     0
# 580   23452509106             Dompet Lavergne by Sophie Martin Paris     0
# 1635   7465287984  DOMPET LIPAT WANITA BAELLERRY ORIGINAL WA130B5...     0
# 3988   8096741757     dompet / pouch - PUFFY MUFFY WALLET | LA.IDEAS     0
#
#       reviews  coin_slot
# 2032        0          0
# 7051        0          0
# 4990        0          0
# 2602        0          0
# 6817        0          0
# 429         0          0
# 7668        0          1
# 3006        0          0
# 4251        0          0
# 3072        0          0
# 6675        0          0
# 5403        0          0
# 3502        0          0
# 7189        0          0
# 4888        0          0
# 6753        0          0
# 291         0          0
# 580         0          0
# 1635        0          0
# 3988        0          0

# %%
# ── Print a structured audit summary ──────────────────────────────
print("=" * 58)
print("  PHASE 1 AUDIT SUMMARY AFTER MANIPULATION")
print("=" * 58)
print(f"  Rows            : {len(audit_df):,}")
print(f"  Columns         : {audit_df.shape[1]}")
print(f"  Full duplicates : {audit_df.duplicated().sum()}")
print(f"  Cols w/ nulls   : {audit_df.isnull().any().sum()}")
print(f"  Zero-rating rows: {(audit_df['rating']==0).sum()} — exclude from roadmap modeling")
print(f"  Zero-review rows: {(audit_df['reviews']==0).sum()} — likely new/inactive listings")
print(f"  Zero-sold rows  : {(audit_df['sold']==0).sum()} — tag as 'no traction' segment")
print(f"  Max reviews     : {audit_df['reviews'].max():,} — extreme right skew → log-transform")
print(f"  Max GMV         : IDR {audit_df['gmv_cal'].max():,.0f} → log-transform")
print(f"  Rating median   : {audit_df['rating'].median()} (mean {audit_df['rating'].mean():.3f})")
print("─" * 58)
# Out:
# ==========================================================
#   PHASE 1 AUDIT SUMMARY AFTER MANIPULATION
# ==========================================================
#   Rows            : 4,154
#   Columns         : 37
#   Full duplicates : 0
#   Cols w/ nulls   : 0
#   Zero-rating rows: 3 — exclude from roadmap modeling
#   Zero-review rows: 38 — likely new/inactive listings
#   Zero-sold rows  : 36 — tag as 'no traction' segment
#   Max reviews     : 49,830 — extreme right skew → log-transform
#   Max GMV         : IDR 5,746,629,000 → log-transform
#   Rating median   : 4.89 (mean 4.849)
# ──────────────────────────────────────────────────────────

# %%
audit_df.describe()
# Out:
#                  id       rating       reviews  initial_price    final_price  \
# count  4.154000e+03  4154.000000   4154.000000   4.154000e+03    4154.000000
# mean   1.452962e+10     4.848830    451.757583   1.412304e+05   83143.488880
# min    2.438520e+07     0.000000      0.000000   5.000000e+03    3999.000000
# 25%    8.113811e+09     4.810000      5.000000   8.500000e+04   52000.000000
# 50%    1.643621e+10     4.890000     29.000000   1.300000e+05   70000.000000
# 75%    2.093548e+10     5.000000    156.750000   1.750000e+05   89900.000000
# max    2.886636e+10     5.000000  49830.000000   1.339000e+06  600000.000000
# std    7.210249e+09     0.260291   2109.167409   9.970318e+04   60346.839436
#
#               stock     favorite  seller_rating  seller_products  \
# count  4.154000e+03  4154.000000    4154.000000      4154.000000
# mean   2.227453e+03   114.065479       4.836810       346.468223
# min    0.000000e+00     0.000000       1.350000         5.000000
# 25%    1.000000e+01     6.000000       4.800000       149.250000
# 50%    9.200000e+01    26.000000       4.850000       285.000000
# 75%    7.025000e+02   110.750000       4.890000       517.000000
# max    1.727036e+06   997.000000       5.000000      4356.000000
# std    3.084009e+04   198.043603       0.093631       261.545978
#
#        seller_chats_responded_percentage  ...             seller_joined_date  \
# count                        4154.000000  ...                           4154
# mean                           90.165383  ...  1970-01-01 00:00:05.266387847
# min                             3.000000  ...  1970-01-01 00:00:00.104038329
# 25%                            87.000000  ...            1970-01-01 00:00:04
# 50%                            95.000000  ...            1970-01-01 00:00:06
# 75%                            99.000000  ...            1970-01-01 00:00:07
# max                           100.000000  ...  1970-01-01 00:00:10.050650239
# std                            13.362740  ...                            NaN
#
#       seller_followers          sold       gmv_cal    coin_slot  \
# count     4.154000e+03   4154.000000  4.154000e+03  4154.000000
# mean      1.390045e+05    750.288397  4.921387e+07     0.180067
# min       0.000000e+00      0.000000  0.000000e+00     0.000000
# 25%       4.092500e+03     11.000000  7.620750e+05     0.000000
# 50%       2.860000e+04     67.000000  4.593625e+06     0.000000
# 75%       2.326000e+05    373.000000  2.638970e+07     0.000000
# max       1.266960e+06  54813.000000  5.746629e+09     1.000000
# std       2.036868e+05   2520.027677  1.961050e+08     0.384290
#
#        variations_count  voucher_status  image_count  video_count  \
# count       4154.000000     4154.000000  4154.000000  4154.000000
# mean           5.236639        0.001685     8.597256     0.572220
# min            0.000000        0.000000     1.000000     0.000000
# 25%            2.000000        0.000000     8.000000     0.000000
# 50%            5.000000        0.000000     8.000000     1.000000
# 75%            8.000000        0.000000    10.000000     1.000000
# max           50.000000        1.000000    44.000000     1.000000
# std            4.884468        0.041021     2.025910     0.494816
#
#             discount
# count    4154.000000
# mean    58086.911821
# min         0.000000
# 25%     20000.000000
# 50%     50000.000000
# 75%     79000.000000
# max    920000.000000
# std     57859.541273
#
# [8 rows x 21 columns]

# %%
audit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4154 entries, 217 to 989
# Data columns (total 37 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 4154 non-null   int64
#  1   title                              4154 non-null   object
#  2   rating                             4154 non-null   float64
#  3   reviews                            4154 non-null   int64
#  4   initial_price                      4154 non-null   float64
#  5   final_price                        4154 non-null   float64
#  6   stock                              4154 non-null   int64
#  7   favorite                           4154 non-null   int64
#  8   seller_name                        4154 non-null   object
#  9   breadcrumb                         4154 non-null   object
#  10  seller_rating                      4154 non-null   float64
#  11  seller_products                    4154 non-null   int64
#  12  seller_chats_responded_percentage  4154 non-null   int64
#  13  seller_chat_time_reply             4154 non-null   float64
#  14  seller_joined_date                 4154 non-null   datetime64[ns]
#  15  seller_followers                   4154 non-null   int64
#  16  sold                               4154 non-null   int64
#  17  brand                              4154 non-null   object
#  18  gmv_cal                            4154 non-null   float64
#  19  motif                              4154 non-null   object
#  20  warranty_type                      4154 non-null   object
#  21  material                           4154 non-null   object
#  22  warranty_duration                  4154 non-null   object
#  23  country_of_origin                  4154 non-null   object
#  24  closure_type                       4154 non-null   object
#  25  card_slots                         4154 non-null   object
#  26  coin_slot                          4154 non-null   int8
#  27  leather_texture                    4154 non-null   object
#  28  leather_finish                     4154 non-null   object
#  29  leather_type                       4154 non-null   object
#  30  shipped_from_region                4154 non-null   object
#  31  variations_count                   4154 non-null   int64
#  32  voucher_status                     4154 non-null   int8
#  33  image_count                        4154 non-null   int64
#  34  video_count                        4154 non-null   int8
#  35  discount                           4154 non-null   float64
#  36  wallet_type                        4154 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(10), int8(3), object(16)
# memory usage: 1.1+ MB

# %%
audit_df.describe()
# Out:
#                  id       rating       reviews  initial_price    final_price  \
# count  4.154000e+03  4154.000000   4154.000000   4.154000e+03    4154.000000
# mean   1.452962e+10     4.848830    451.757583   1.412304e+05   83143.488880
# min    2.438520e+07     0.000000      0.000000   5.000000e+03    3999.000000
# 25%    8.113811e+09     4.810000      5.000000   8.500000e+04   52000.000000
# 50%    1.643621e+10     4.890000     29.000000   1.300000e+05   70000.000000
# 75%    2.093548e+10     5.000000    156.750000   1.750000e+05   89900.000000
# max    2.886636e+10     5.000000  49830.000000   1.339000e+06  600000.000000
# std    7.210249e+09     0.260291   2109.167409   9.970318e+04   60346.839436
#
#               stock     favorite  seller_rating  seller_products  \
# count  4.154000e+03  4154.000000    4154.000000      4154.000000
# mean   2.227453e+03   114.065479       4.836810       346.468223
# min    0.000000e+00     0.000000       1.350000         5.000000
# 25%    1.000000e+01     6.000000       4.800000       149.250000
# 50%    9.200000e+01    26.000000       4.850000       285.000000
# 75%    7.025000e+02   110.750000       4.890000       517.000000
# max    1.727036e+06   997.000000       5.000000      4356.000000
# std    3.084009e+04   198.043603       0.093631       261.545978
#
#        seller_chats_responded_percentage  ...             seller_joined_date  \
# count                        4154.000000  ...                           4154
# mean                           90.165383  ...  1970-01-01 00:00:05.266387847
# min                             3.000000  ...  1970-01-01 00:00:00.104038329
# 25%                            87.000000  ...            1970-01-01 00:00:04
# 50%                            95.000000  ...            1970-01-01 00:00:06
# 75%                            99.000000  ...            1970-01-01 00:00:07
# max                           100.000000  ...  1970-01-01 00:00:10.050650239
# std                            13.362740  ...                            NaN
#
#       seller_followers          sold       gmv_cal    coin_slot  \
# count     4.154000e+03   4154.000000  4.154000e+03  4154.000000
# mean      1.390045e+05    750.288397  4.921387e+07     0.180067
# min       0.000000e+00      0.000000  0.000000e+00     0.000000
# 25%       4.092500e+03     11.000000  7.620750e+05     0.000000
# 50%       2.860000e+04     67.000000  4.593625e+06     0.000000
# 75%       2.326000e+05    373.000000  2.638970e+07     0.000000
# max       1.266960e+06  54813.000000  5.746629e+09     1.000000
# std       2.036868e+05   2520.027677  1.961050e+08     0.384290
#
#        variations_count  voucher_status  image_count  video_count  \
# count       4154.000000     4154.000000  4154.000000  4154.000000
# mean           5.236639        0.001685     8.597256     0.572220
# min            0.000000        0.000000     1.000000     0.000000
# 25%            2.000000        0.000000     8.000000     0.000000
# 50%            5.000000        0.000000     8.000000     1.000000
# 75%            8.000000        0.000000    10.000000     1.000000
# max           50.000000        1.000000    44.000000     1.000000
# std            4.884468        0.041021     2.025910     0.494816
#
#             discount
# count    4154.000000
# mean    58086.911821
# min         0.000000
# 25%     20000.000000
# 50%     50000.000000
# 75%     79000.000000
# max    920000.000000
# std     57859.541273
#
# [8 rows x 21 columns]

# %%
audit_df[['title', 'motif', 'warranty_type', 'material', 'warranty_duration', 'leather_type', 'leather_texture', 'leather_finish', 'card_slots', 'coin_slot']]
# Out:
#                                                   title       motif  \
# 217   BAELLERRY 1063 Dompet Panjang Pria Kulit Long ...       Solid
# 7253  Dompet Lipat Pria Kulit Branded MENBENSE ORIGINAL     Unknown
# 213   Smile Goddess Dompet Wanita Baru Bergaya Pemeg...     Unknown
# 8177  TASBLUE Dompet Wanita Korea Baru Dompet Koin R...  Print/Logo
# 1133  HEYLOOK Official - Dompet Pria Trafford Dompet...       Solid
# ...                                                 ...         ...
# 5868  hokkiterus21 DOMPET POUCH CHARGER HANDSFREE ta...     Unknown
# 7721  Tas Ipad Tablet 8/11 Inch Ipad Soft Case Pelin...     Unknown
# 3912  Dompet Kartu Wanita Ruang Ganda Double Resleti...      Floral
# 3096  Dompet Wanita Kulit Asli - Floflap Wallet by W...      Floral
# 989   Tas Dompet Kosmetik WASHBAG Transparant Pouch ...     Unknown
#
#           warranty_type                  material warranty_duration  \
# 217   Supplier Warranty           Genuine Leather        Short Term
# 7253        No Warranty  Special Texture & Others       No Warranty
# 213         No Warranty  Special Texture & Others       No Warranty
# 8177        No Warranty         Synthetic Leather       No Warranty
# 1133  Supplier Warranty         Synthetic Leather       Medium Term
# ...                 ...                       ...               ...
# 5868        No Warranty  Special Texture & Others       No Warranty
# 7721        No Warranty  Special Texture & Others       No Warranty
# 3912        No Warranty         Synthetic Leather       Medium Term
# 3096        No Warranty           Genuine Leather        Short Term
# 989         No Warranty  Special Texture & Others       No Warranty
#
#            leather_type leather_texture leather_finish card_slots  coin_slot
# 217   Synthetic Leather          Smooth          Matte       > 10          1
# 7253      Uncategorized           Other          Other          0          0
# 213       Uncategorized           Other          Other          0          0
# 8177              Other         Layered          Matte          4          0
# 1133      Uncategorized           Other          Other          6          0
# ...                 ...             ...            ...        ...        ...
# 5868      Uncategorized           Other          Other          0          0
# 7721      Uncategorized           Other          Other          0          0
# 3912              Other          Smooth         Glossy       > 10          0
# 3096      Uncategorized           Other          Other          0          0
# 989       Uncategorized           Other          Other          0          0
#
# [4154 rows x 10 columns]

# %%
audit_df['warranty_type'].value_counts(dropna=False)
# Out:
# warranty_type
# No Warranty               3536
# Supplier Warranty          400
# Manufacturer Warranty      177
# Seller Warranty             25
# International Warranty      16
# Name: count, dtype: int64

# %%
audit_df['material'].value_counts(dropna=False)
# Out:
# material
# Special Texture & Others     1747
# Synthetic Leather            1543
# Fabric & Textile              461
# Genuine Leather               268
# Technical & Waterproof        116
# Hardware & Hard Materials      19
# Name: count, dtype: int64

# %%
audit_df.to_csv("./data/dompet_final_cleaned_v2.csv", index=False)
